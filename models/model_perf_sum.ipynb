# %%
import pandas as pd
import numpy as np
cities_all=['Berlin','Dresden','Düsseldorf','Frankfurt am Main','Kassel','Leipzig','Magdeburg','Potsdam','Clermont','Dijon','Lille','Lyon','Montpellier','Nantes','Nimes','Paris','Toulouse','Madrid','Wien','France_other','Germany_other','All']
#cities_all=['Berlin','Dresden','Düsseldorf','Frankfurt am Main','Kassel','Leipzig','Magdeburg','Potsdam','Clermont','Dijon','Lille','Lyon','Montpellier','Nantes','Nimes','Paris','Toulouse','Madrid','Wien','France_other','Germany_other']
cities_car=['Berlin','Dresden','Düsseldorf','Frankfurt am Main','Kassel','Leipzig','Magdeburg','Potsdam','Clermont','Paris','Toulouse','France_other','Germany_other','All']

# %%
cities=[]

dist_agg_ml=[]
dist_agg_lr=[]

dist_comm_ml=[]
dist_comm_lr=[]

carown_ml=[]
carown_lr=[]

mode_ml=[]
mode_lr=[]

# %%
for city in cities_all:
    print(city)
    fp='../outputs/ML_Results/' + city + '_HPO_dist_agg_summary.csv'
    dist_agg=pd.read_csv(fp)

    dist_agg_ml.append(round(dist_agg['R2_full_ML'][0],3))
    dist_agg_lr.append(round(dist_agg['R2_full_LR'][0],3))

    fp='../outputs/ML_Results/' + city + '_HPO_dist_commute_summary.csv'
    dist_commute=pd.read_csv(fp)

    dist_comm_ml.append(round(dist_commute['R2_full_ML'][0],3))
    dist_comm_lr.append(round(dist_commute['R2_full_LR'][0],3))

    fp='../outputs/ML_Results/' + city + '_HPO_mode_common_new_summary.csv'
    mode=pd.read_csv(fp)

    mode_ml.append(round(mode['F1_full_ML'][0],3))
    mode_lr.append(round(mode['F1_full_LR'][0],3))

    cities.append(city)
# Out:
# Berlin
# Dresden
# Düsseldorf
# Frankfurt am Main
# Kassel
# Leipzig
# Magdeburg
# Potsdam
# Clermont
# Dijon
# Lille
# Lyon
# Montpellier
# Nantes
# Nimes
# Paris
# Toulouse
# Madrid
# Wien
# France_other
# Germany_other
# All

# %%
for city in cities_car:
    print(city)

    fp='../outputs/ML_Results/' + city + '_HPO_carown_new_summary.csv'
    carown=pd.read_csv(fp)

    carown_ml.append(round(carown['F1_full_ML'][0],3))
    carown_lr.append(round(carown['F1_full_LR'][0],3))
# Out:
# Berlin
# Dresden
# Düsseldorf
# Frankfurt am Main
# Kassel
# Leipzig
# Magdeburg
# Potsdam
# Clermont
# Paris
# Toulouse
# France_other
# Germany_other
# All

# %%
carown_df=pd.DataFrame({'city':cities_car,'car_own_F1_ML':carown_ml,'car_own_F1_LR':carown_lr})
carown_df
# Out:
#                  city  car_own_F1_ML  car_own_F1_LR
# 0              Berlin          0.756          0.738
# 1             Dresden          0.813          0.784
# 2          Düsseldorf          0.800          0.796
# 3   Frankfurt am Main          0.793          0.797
# 4              Kassel          0.833          0.826
# 5             Leipzig          0.769          0.749
# 6           Magdeburg          0.812          0.796
# 7             Potsdam          0.767          0.773
# 8            Clermont          0.832          0.830
# 9               Paris          0.761          0.744
# 10           Toulouse          0.845          0.845
# 11       France_other          0.845          0.842
# 12      Germany_other          0.807          0.786
# 13                All          0.783          0.758

# %%
summ_df=pd.DataFrame({'city':cities,'dist_agg_r2_ML':dist_agg_ml,'dist_agg_r2_LR':dist_agg_lr,
                      'dist_commute_r2_ML':dist_comm_ml,'dist_commute_r2_LR':dist_comm_lr,
                      'mode_F1_ML':mode_ml,'mode_F1_LR':mode_lr})

summ_df
# Out:
#                  city  dist_agg_r2_ML  dist_agg_r2_LR  dist_commute_r2_ML  \
# 0              Berlin           0.780           0.813               0.145
# 1             Dresden           0.270           0.272              -0.064
# 2          Düsseldorf           0.167          -0.042               0.030
# 3   Frankfurt am Main           0.045          -0.609              -0.082
# 4              Kassel          -0.746          -7.722              -0.099
# 5             Leipzig           0.454           0.336               0.021
# 6           Magdeburg          -0.021          -8.137              -0.008
# 7             Potsdam          -1.090          -5.295              -0.041
# 8            Clermont           0.111           0.138               0.221
# 9               Dijon           0.505           0.627               0.137
# 10              Lille           0.172           0.268               0.117
# 11               Lyon           0.425           0.467               0.160
# 12        Montpellier           0.700           0.769               0.207
# 13             Nantes           0.652           0.666               0.184
# 14              Nimes           0.345          -0.640               0.167
# 15              Paris           0.500           0.578               0.128
# 16           Toulouse           0.406           0.545               0.175
# 17             Madrid           0.672           0.669               0.173
# 18               Wien           0.493           0.420               0.085
# 19       France_other           0.407           0.445               0.213
# 20      Germany_other           0.141           0.096               0.052
# 21                All           0.528           0.530               0.158
#
#     dist_commute_r2_LR  mode_F1_ML  mode_F1_LR
# 0                0.140       0.677       0.625
# 1               -0.010       0.678       0.617
# 2                0.029       0.648       0.600
# 3               -0.012       0.654       0.583
# 4               -0.017       0.684       0.626
# 5                0.035       0.683       0.640
# 6                0.039       0.694       0.637
# 7               -0.007       0.664       0.608
# 8                0.252       0.914       0.646
# 9                0.210       0.876       0.698
# 10               0.103       0.903       0.799
# 11               0.151       0.871       0.672
# 12               0.207       0.875       0.743
# 13               0.175       0.857       0.753
# 14               0.185       0.911       0.596
# 15               0.091       0.788       0.500
# 16               0.155       0.863       0.735
# 17               0.134       0.727       0.685
# 18               0.110       0.685       0.661
# 19               0.178       0.884       0.764
# 20               0.022       0.672       0.616
# 21               0.121       0.758       0.678

# %%
summ_df=summ_df.merge(carown_df,how='outer')
summ_df
# Out:
#                  city  dist_agg_r2_ML  dist_agg_r2_LR  dist_commute_r2_ML  \
# 0              Berlin           0.780           0.813               0.145
# 1             Dresden           0.270           0.272              -0.064
# 2          Düsseldorf           0.167          -0.042               0.030
# 3   Frankfurt am Main           0.045          -0.609              -0.082
# 4              Kassel          -0.746          -7.722              -0.099
# 5             Leipzig           0.454           0.336               0.021
# 6           Magdeburg          -0.021          -8.137              -0.008
# 7             Potsdam          -1.090          -5.295              -0.041
# 8            Clermont           0.111           0.138               0.221
# 9               Dijon           0.505           0.627               0.137
# 10              Lille           0.172           0.268               0.117
# 11               Lyon           0.425           0.467               0.160
# 12        Montpellier           0.700           0.769               0.207
# 13             Nantes           0.652           0.666               0.184
# 14              Nimes           0.345          -0.640               0.167
# 15              Paris           0.500           0.578               0.128
# 16           Toulouse           0.406           0.545               0.175
# 17             Madrid           0.672           0.669               0.173
# 18               Wien           0.493           0.420               0.085
# 19       France_other           0.407           0.445               0.213
# 20      Germany_other           0.141           0.096               0.052
# 21                All           0.528           0.530               0.158
#
#     dist_commute_r2_LR  mode_F1_ML  mode_F1_LR  car_own_F1_ML  car_own_F1_LR
# 0                0.140       0.677       0.625          0.756          0.738
# 1               -0.010       0.678       0.617          0.813          0.784
# 2                0.029       0.648       0.600          0.800          0.796
# 3               -0.012       0.654       0.583          0.793          0.797
# 4               -0.017       0.684       0.626          0.833          0.826
# 5                0.035       0.683       0.640          0.769          0.749
# 6                0.039       0.694       0.637          0.812          0.796
# 7               -0.007       0.664       0.608          0.767          0.773
# 8                0.252       0.914       0.646          0.832          0.830
# 9                0.210       0.876       0.698            NaN            NaN
# 10               0.103       0.903       0.799            NaN            NaN
# 11               0.151       0.871       0.672            NaN            NaN
# 12               0.207       0.875       0.743            NaN            NaN
# 13               0.175       0.857       0.753            NaN            NaN
# 14               0.185       0.911       0.596            NaN            NaN
# 15               0.091       0.788       0.500          0.761          0.744
# 16               0.155       0.863       0.735          0.845          0.845
# 17               0.134       0.727       0.685            NaN            NaN
# 18               0.110       0.685       0.661            NaN            NaN
# 19               0.178       0.884       0.764          0.845          0.842
# 20               0.022       0.672       0.616          0.807          0.786
# 21               0.121       0.758       0.678          0.783          0.758

# %%
summ_df.to_csv('../outputs/ML_Results/accuracy_all.csv',index=False)
