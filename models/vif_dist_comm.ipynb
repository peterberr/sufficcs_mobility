# %% [markdown]
# ## Correlation and Variance Inflation, Trip Distance (commute)

# %% [markdown]
# This is a notebook to compute variance inflation factors and correlation coefficients between urban form and selected other features for models of commute trip distance in 19 European cities.
#
# In general, we try to avoid VIF>5, and correlation factors > 0.7 (absolute value)

# %%
# script to model avergage trip distances for commute trips in all cities
# last update Peter Berrill Nov 20 2023

# load in required packages
import numpy as np
import pandas as pd
import shap
import re
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, cross_validate, GroupKFold, StratifiedGroupKFold, RepeatedKFold, StratifiedKFold, GridSearchCV, KFold
from sklearn import metrics, linear_model
from xgboost import XGBClassifier, XGBRegressor
import os
import sys
import matplotlib.pyplot as plt
import pickle
import statsmodels.formula.api as smf
from datetime import datetime
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import seaborn as sns

cities_all=['Berlin','Dresden','Düsseldorf','Frankfurt am Main','Kassel','Leipzig','Magdeburg','Potsdam','Clermont','Dijon','Lille','Lyon','Montpellier','Nantes','Nimes','Paris','Toulouse','Madrid','Wien','France_other','Germany_other']
countries=['Germany','Germany','Germany','Germany','Germany','Germany','Germany','Germany','France','France','France','France','France','France','France','France','France','Spain','Austria','France','Germany']
# Out:
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.

# %%
def vif_corr(city):
    country=countries[cities_all.index(city)]
    print(city, country)
    if city=='Germany_other':
        city0='Dresden'
        df0=pd.read_csv('../outputs/Combined/' + city0 + '_UF.csv')
        df0.loc[(df0['Training'].isin(['Apprenticeship/Business','Craftsman/Technical'])) & (df0['Education']!='University'),'Education']='Apprenticeship'
        df0=df0.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
                    'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
                    'Sex', 'Occupation', 'Education','Age',
                    #'PopDensity_res','BuildDensity_res',
                    'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
                    'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                    'LU_Comm_res' ,'Trip_Distance']]
        df0['City']=city0
        df_all=df0.copy()

        cities0=['Leipzig','Magdeburg','Potsdam','Frankfurt am Main','Düsseldorf','Kassel']
        for city1 in cities0:
                df1=pd.read_csv('../outputs/Combined/' + city1 + '_UF.csv')
                df1.loc[(df1['Training'].isin(['Apprenticeship/Business','Craftsman/Technical'])) & (df1['Education']!='University'),'Education']='Apprenticeship'
                df1=df1.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
                            'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
                            'Sex', 'Occupation', 'Education','Age',
                            #'PopDensity_res','BuildDensity_res',
                            'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
                            'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                            'LU_Comm_res','Trip_Distance']]
                df1['City']=city1
                if len(df1.columns==df_all.columns):
                       df_all=pd.concat([df_all,df1])
        df_all['HHNR']=df_all['City']+'_'+df_all['HHNR'].astype(int).astype(str)
        df_all['HH_PNR']=df_all['City']+'_'+df_all['HH_PNR'].astype(int).astype(str)
        df_all['HH_P_WNR']=df_all['City']+'_'+df_all['HH_P_WNR'].astype(str)
        df_all.drop(columns='City',inplace=True)
        df_UF=df_all.copy()
    elif city=='France_other':
        city0='Clermont'
        df0=pd.read_csv('../outputs/Combined/' + city0 + '_UF.csv')
        df0=df0.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
                    'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
                    'Sex', 'Occupation', 'Education','Age',
                    #'PopDensity_res','BuildDensity_res',
                    'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
                    'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                    'LU_Comm_res', 'Trip_Distance']]
        df0['City']=city0
        df_all=df0.copy()

        cities0=['Toulouse','Montpellier','Lyon','Nantes','Nimes','Lille','Dijon']
        for city1 in cities0:
                df1=pd.read_csv('../outputs/Combined/' + city1 + '_UF.csv')
                df1=df1.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
                            'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
                            'Sex', 'Occupation', 'Education','Age',
                            #'PopDensity_res','BuildDensity_res',
                            'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
                            'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                            'LU_Comm_res', 'Trip_Distance']]
                df1['City']=city1
                if len(df1.columns==df_all.columns):
                       df_all=pd.concat([df_all,df1])
        df_all['HHNR']=df_all['City']+'_'+df_all['HHNR'].astype(int).astype(str)
        df_all['HH_PNR']=df_all['City']+'_'+df_all['HH_PNR'].astype(int).astype(str)
        df_all['HH_P_WNR']=df_all['City']+'_'+df_all['HH_P_WNR'].astype(str)
        df_all.drop(columns='City',inplace=True)
        df_UF=df_all.copy()
    else:
            df=pd.read_csv('../outputs/Combined/' + city + '_UF.csv',dtype={'Ori_geocode': str, 'Des_geocode': str,'Res_geocode': str })
            if country=='Germany':
                df.loc[(df['Training'].isin(['Apprenticeship/Business','Craftsman/Technical'])) & (df['Education']!='University'),'Education']='Apprenticeship'
            df_UF=df.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
                            'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
                            'Sex', 'Occupation', 'Education','Age',
                            #'PopDensity_res','BuildDensity_res',
                            'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
                            'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                            'LU_Comm_res', 'Trip_Distance']]
    # restrict to trips between home and work (commuting trips)        
    df_UF=df_UF.loc[df_UF['Trip_Purpose_Agg']=='Home↔Work',]
    df_UF.drop(columns='Trip_Purpose_Agg',inplace=True)
    # restrict to those in employment
    df_UF=df_UF.loc[df_UF['Occupation'].isin(['Trainee','Employed_FullTime','Employed_PartTime','Employed']),]

    Edu_dict={'University':'University','Secondary':'Secondary','Secondary+BAC':'Secondary','Secondary+Matura':'Secondary',
          'Apprenticeship':'Apprenticeship',
          'Elementary':'Primary/None','Pre-School':'Primary/None','No diploma yet':'Primary/None','Unknown':'Primary/None','Other':'Primary/None'}

    df_UF['Education']=df_UF['Education'].map(Edu_dict)
    if city in ['Clermont','Nimes']:
          df_UF.loc[df_UF['Education']=='Apprenticeship','Education']='Secondary'

    df=df_UF.dropna()
    df['Sex']=df['Sex']-1 # change from [1,2] to [0,1], for plotting purposes
    df=df.loc[df['UrbBuildDensity_res']<1e8,]   # remove high building density outliers (For Leipzig)

    # identify the feature columns
    N_non_feature=6 # how many non-features are at the start of the df
    cols=df.columns
    newcols=(df.columns[:N_non_feature].tolist()) + ('FeatureD' +'_'+ cols[N_non_feature:-1]).tolist() + (df.columns[-1:].tolist())
    # change column names
    df.set_axis(newcols,axis=1,inplace=True)
    df = df.reset_index(drop=True)
    df0=df.copy()

    # convert  all categorical variables to dummies
    df_Cat=df.select_dtypes('object')[[col for col in df.select_dtypes('object').columns if "FeatureD" in col]]
    for col in df_Cat:
        dum=pd.get_dummies(df[[col]])
        df = pd.concat([df, dum], axis = 1)
        # remove the original categorical columns
    df.drop(df_Cat.columns.tolist(),axis=1,inplace=True)

    X=df[[col for col in df.columns if "FeatureD" in col]]
    return X

# %%
X=vif_corr('Berlin')
X_disp=[re.sub('FeatureD_','', x) for x in X.columns]
X.columns=X_disp
X = X[X.columns.drop(list(X.filter(regex='Education')))]
X = X[X.columns.drop(list(X.filter(regex='Season')))]
X = X[X.columns.drop(list(X.filter(regex='Trip_Time')))]
X = X[X.columns.drop(list(X.filter(regex='Occupation')))]
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Berlin Germany
#                 Feature         VIF
# 0                 const  227.031972
# 1                HHSize    1.049988
# 2                   Sex    1.004526
# 3                   Age    1.084612
# 4     UrbPopDensity_res    4.185069
# 5   UrbBuildDensity_res    4.025003
# 6     DistSubcenter_res    1.408009
# 7        DistCenter_res    3.046970
# 8   IntersecDensity_res    2.917028
# 9     street_length_res    1.935022
# 10        LU_UrbFab_res    1.930529
# 11          LU_Comm_res    1.959696
# <style type="text/css">
# #T_a38fc_row0_col0, #T_a38fc_row1_col1, #T_a38fc_row2_col2, #T_a38fc_row3_col3, #T_a38fc_row4_col4, #T_a38fc_row5_col5, #T_a38fc_row6_col6, #T_a38fc_row7_col7, #T_a38fc_row8_col8, #T_a38fc_row9_col9, #T_a38fc_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_
col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1d2ee_row9_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1d2ee_row9_col3 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_1d2ee_row9_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_1d2ee_row9_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_1d2ee_row9_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# </style>
# <table id="T_1d2ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d2ee_level0_col0" class="col_heading level0 col0" >HHSize</th>
#       <th id="T_1d2ee_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_1d2ee_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_1d2ee_level0_col3" class="col_heading level0 col3" >UrbPopDensity_res</th>
#       <th id="T_1d2ee_level0_col4" class="col_heading level0 col4" >DistSubcenter_res</th>
#       <th id="T_1d2ee_level0_col5" class="col_heading level0 col5" >DistCenter_res</th>
#       <th id="T_1d2ee_level0_col6" class="col_heading level0 col6" >IntersecDensity_res</th>
#       <th id="T_1d2ee_level0_col7" class="col_heading level0 col7" >street_length_res</th>
#       <th id="T_1d2ee_level0_col8" class="col_heading level0 col8" >LU_UrbFab_res</th>
#       <th id="T_1d2ee_level0_col9" class="col_heading level0 col9" >LU_Comm_res</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d2ee_level0_row0" class="row_heading level0 row0" >HHSize</th>
#       <td id="T_1d2ee_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_1d2ee_row0_col1" class="data row0 col1" >-0.063</td>
#       <td id="T_1d2ee_row0_col2" class="data row0 col2" >-0.127</td>
#       <td id="T_1d2ee_row0_col3" class="data row0 col3" >-0.084</td>
#       <td id="T_1d2ee_row0_col4" class="data row0 col4" >0.085</td>
#       <td id="T_1d2ee_row0_col5" class="data row0 col5" >0.094</td>
#       <td id="T_1d2ee_row0_col6" class="data row0 col6" >-0.022</td>
#       <td id="T_1d2ee_row0_col7" class="data row0 col7" >0.035</td>
#       <td id="T_1d2ee_row0_col8" class="data row0 col8" >0.029</td>
#       <td id="T_1d2ee_row0_col9" class="data row0 col9" >-0.076</td>
#     </tr>
#     <tr>
#       <th id="T_1d2ee_level0_row1" class="row_heading level0 row1" >Sex</th>
#       <td id="T_1d2ee_row1_col0" class="data row1 col0" >-0.063</td>
#       <td id="T_1d2ee_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_1d2ee_row1_col2" class="data row1 col2" >0.003</td>
#       <td id="T_1d2ee_row1_col3" class="data row1 col3" >-0.001</td>
#       <td id="T_1d2ee_row1_col4" class="data row1 col4" >0.005</td>
#       <td id="T_1d2ee_row1_col5" class="data row1 col5" >0.009</td>
#       <td id="T_1d2ee_row1_col6" class="data row1 col6" >0.003</td>
#       <td id="T_1d2ee_row1_col7" class="data row1 col7" >-0.006</td>
#       <td id="T_1d2ee_row1_col8" class="data row1 col8" >0.003</td>
#       <td id="T_1d2ee_row1_col9" class="data row1 col9" >-0.004</td>
#     </tr>
#     <tr>
#       <th id="T_1d2

# %%
X=vif_corr('Paris')
X_disp=[re.sub('FeatureD_','', x) for x in X.columns]
X.columns=X_disp
X = X[X.columns.drop(list(X.filter(regex='Education')))]
X = X[X.columns.drop(list(X.filter(regex='Season')))]
X = X[X.columns.drop(list(X.filter(regex='Trip_Time')))]
X = X[X.columns.drop(list(X.filter(regex='Occupation')))]
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Paris France
#                 Feature         VIF
# 0                 const  376.262980
# 1                HHSize    1.046552
# 2                   Sex    1.007918
# 3                   Age    1.009086
# 4     UrbPopDensity_res    5.519999
# 5   UrbBuildDensity_res    4.168286
# 6     DistSubcenter_res    1.489145
# 7        DistCenter_res    3.615204
# 8   IntersecDensity_res    4.151349
# 9     street_length_res    2.128021
# 10        LU_UrbFab_res    2.504173
# 11          LU_Comm_res    1.811359
# <style type="text/css">
# #T_81ed6_row0_col0, #T_81ed6_row1_col1, #T_81ed6_row2_col2, #T_81ed6_row3_col3, #T_81ed6_row4_col4, #T_81ed6_row5_col5, #T_81ed6_row6_col6, #T_81ed6_row7_col7, #T_81ed6_row8_col8, #T_81ed6_row9_col9, #T_81ed6_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_81ed6_row0_col1, #T_81ed6_row0_col2, #T_81ed6_row3_col0, #T_81ed6_row3_col6, #T_81ed6_row4_col5, #T_81ed6_row4_col6, #T_81ed6_row6_col3, #T_81ed6_row6_col4, #T_81ed6_row7_col8, #T_81ed6_row8_col7, #T_81ed6_row9_col10, #T_81ed6_row10_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T
row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_81ed6_row0_col1" class="data row0 col1" >-0.075</td>
#       <td id="T_81ed6_row0_col2" class="data row0 col2" >-0.060</td>
#       <td id="T_81ed6_row0_col3" class="data row0 col3" >-0.166</td>
#       <td id="T_81ed6_row0_col4" class="data row0 col4" >-0.154</td>
#       <td id="T_81ed6_row0_col5" class="data row0 col5" >0.066</td>
#       <td id="T_81ed6_row0_col6" class="data row0 col6" >0.168</td>
#       <td id="T_81ed6_row0_col7" class="data row0 col7" >-0.157</td>
#       <td id="T_8

# %% [markdown]
# In Paris, VIFs is high for population density, and other density measures.
#
# Repeating without built-up density leads to notably lower VIFs for population density, it is still a bit high for intersection density (4.1) but acceptable.
#
# Correlation remains high between population density and distance to center (0.772) but we retain these variables due to their high importance.

# %%
# Paris better VIF w/o bld dens
X.drop(columns='UrbBuildDensity_res',inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
#                 Feature         VIF
# 0                 const  374.397246
# 1                HHSize    1.045705
# 2                   Sex    1.007918
# 3                   Age    1.008345
# 4     UrbPopDensity_res    3.450744
# 5     DistSubcenter_res    1.476201
# 6        DistCenter_res    3.407399
# 7   IntersecDensity_res    4.149978
# 8     street_length_res    2.127007
# 9         LU_UrbFab_res    2.485582
# 10          LU_Comm_res    1.691672
# <style type="text/css">
# #T_1fd6b_row0_col0, #T_1fd6b_row1_col1, #T_1fd6b_row2_col2, #T_1fd6b_row3_col3, #T_1fd6b_row4_col4, #T_1fd6b_row5_col5, #T_1fd6b_row6_col6, #T_1fd6b_row7_col7, #T_1fd6b_row8_col8, #T_1fd6b_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1fd6b_row0_col1, #T_1fd6b_row0_col2, #T_1fd6b_row3_col0, #T_1fd6b_row3_col5, #T_1fd6b_row5_col3, #T_1fd6b_row6_col4, #T_1fd6b_row6_col7, #T_1fd6b_row7_col6, #T_1fd6b_row8_col9, #T_1fd6b_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1fd6b_row0_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_1fd6b_row0_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_1fd6b_row0_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_1fd6b_row0_col6, #T_1fd6b_row4_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_1fd6b_row0_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_1fd6b_row0_col8 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_1fd6b_row0_col9, #T_1fd6b_row2_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_1fd6b_row1_col0, #T_1fd6b_row9_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_1fd6b_row1_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_1fd6b_row1_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_1fd6b_row1_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_1fd6b_row1_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_1fd6b_row1_col6, #T_1fd6b_row2_col7 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_1fd6b_row1_col7 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_1fd6b_row1_col8 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_1fd6b_row1_col9, #T_1fd6b_row2_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_1fd6b_row2_col0, #T_1fd6b_row6_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_1fd6b_row2_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_1fd6b_row2_col3 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_1fd6b_row2_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_1fd6b_row2_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_1fd6b_row2_col9 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_1fd6b_row3_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_1fd6b_row3_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_1fd6b_row3_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_1fd6b_row3_col6 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_1fd6b_row3_col7, #T_1fd6b_row4_col6, #T_1fd6b_row7_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_1fd6b_row3_col8 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_1fd6b_row3_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_1fd6b_row4_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_1fd6b_row4_col1, #T_1fd6b_row5_col1, #T_1fd6b_row6_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_1fd6b_row4_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1fd6b_row4_col3, #T_1fd6b_row7_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_1fd6b_row4_col5 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_1fd6b_row4_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_1fd6b_row4_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_1fd6b_row5_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_1fd6b_row5_col2, #T_1fd6b_row5_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_1fd6b_row5_col4 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_1fd6b_row5_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_1fd6b_row5_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_1fd6b_row5_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_1fd6b_row6_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_1fd6b_row6_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_1fd6b_row6_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_1fd6b_row6_col8 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_1fd6b_row6_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_1fd6b_row7_col1, #T_1fd6b_row8_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_1fd6b_row7_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_1fd6b_row7_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_1fd6b_row7_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1fd6b_row7_col5 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_1fd6b_row7_col9 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_1fd6b_row8_col0, #T_1fd6b_row9_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1fd6b_row8_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_1fd6b_row8_col3 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_1fd6b_row8_col4, #T_1fd6b_row9_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_1fd6b_row8_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_1fd6b_row8_col6 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_1fd6b_row8_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_1fd6b_row9_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_1fd6b_row9_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_1fd6b_row9_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_1fd6b_row9_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_1fd6b_row9_col7 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# </style>
# <table id="T_1fd6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fd6b_level0_col0" class="col_heading level0 col0" >HHSize</th>
#       <th id="T_1fd6b_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_1fd6b_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_1fd6b_level0_col3" class="col_heading level0 col3" >UrbPopDensity_res</th>
#       <th id="T_1fd6b_level0_col4" class="col_heading level0 col4" >DistSubcenter_res</th>
#       <th id="T_1fd6b_level0_col5" class="col_heading level0 col5" >DistCenter_res</th>
#       <th id="T_1fd6b_level0_col6" class="col_heading level0 col6" >IntersecDensity_res</th>
#       <th id="T_1fd6b_level0_col7" class="col_heading level0 col7" >street_length_res</th>
#       <th id="T_1fd6b_level0_col8" class="col_heading level0 col8" >LU_UrbFab_res</th>
#       <th id="T_1fd6b_level0_col9" class="col_heading level0 col9" >LU_Comm_res</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fd6b_level0_row0" class="row_heading level0 row0" >HHSize</th>
#       <td id="T_1fd6b_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_1fd6b_row0_col1" class="data row0 col1" >-0.075</td>
#       <td id="T_1fd6b_row0_col2" class="data row0 col2" >-0.060</td>
#       <td id="T_1fd6b_row0_col3" class="data row0 col3" >-0.166</td>
#       <td id="T_1fd6b_row0_col4" class="data row0 col4" >0.066</td>
#       <td id="T_1fd6b_row0_col5" class="data row0 col5" >0.168</td>
#       <td id="T_1fd6b_row0_col6" class="data row0 col6" >-0.157</td>
#       <td id="T_1fd6b_row0_col7" class="data row0 col7" >0.095</td>
#       <td id="T_1fd6b_row0_col8" class="data row0 col8" >-0.111</td>
#       <td id="T_1fd6b_row0_col9" class="data row0 col9" >0.076</td>
#     </tr>
#     <tr>
#       <th id="T_1fd6b_level0_row1" class="row_heading level0 row1" >Sex</th>
#       <td id="T_1fd6b_row1_col0" class="data row1 col0" >-0.075</td>
#       <td id="T_1fd6b_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_1fd6b_row1_col2" class="data row1 col2" >0.042</td>
#       <td id="T_1fd6b_row1_col3" class="data row1 col3" >0.008</td>
#       <td id="T_1fd6b_row1_col4" class="data row1 col4" >0.001</td>
#       <td id="T_1fd6b_row1_col5" class="data row1 col5" >0.000</td>
#       <td id="T_1fd6b_row1_col6" class="data row1 col6" >0.000</td>
#       <td id="T_1fd6b_row1_col7" class="data row1 col7" >-0.006</td>
#       <td id="T_1fd6b_row1_col8" class="data row1 col8" >-0.008</td>
#       <td id="T_1fd6b_row1_col9" class="data row1 col9" >0.011</td>
#     </tr>
#     <tr>
#       <th id="T_1fd6b_level0_row2" class="row_heading level0 row2" >Ag

# %%
X=vif_corr('Madrid')
X_disp=[re.sub('FeatureD_','', x) for x in X.columns]
X.columns=X_disp
X = X[X.columns.drop(list(X.filter(regex='Education')))]
X = X[X.columns.drop(list(X.filter(regex='Season')))]
X = X[X.columns.drop(list(X.filter(regex='Trip_Time')))]
X = X[X.columns.drop(list(X.filter(regex='Occupation')))]
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Madrid Spain
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 Feature         VIF
# 0                 const  222.577266
# 1                HHSize    1.029913
# 2                   Sex    1.001847
# 3                   Age    1.017704
# 4     UrbPopDensity_res    2.380048
# 5   UrbBuildDensity_res    1.248022
# 6     DistSubcenter_res    1.282889
# 7        DistCenter_res    1.594868
# 8   IntersecDensity_res    2.718169
# 9     street_length_res    2.072874
# 10        LU_UrbFab_res    2.098204
# 11          LU_Comm_res    1.311277
# <style type="text/css">
# #T_6db89_row0_col0, #T_6db89_row1_col1, #T_6db89_row2_col2, #T_6db89_row3_col3, #T_6db89_row4_col4, #T_6db89_row5_col5, #T_6db89_row6_col6, #T_6db89_row7_col7, #T_6db89_row8_col8, #T_6db89_row9_col9, #T_6db89_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_
level0_row1" class="row_heading level0 row1" >Sex</th>
#       <td id="T_6db89_row1_col0" class="data row1 col0" >-0.035</td>
#       <td id="T_6db89_row1_col1" class="data

# %% [markdown]
# No concerns surrounding VIF or correlations in Madrid.
# However, the highest correlation factor between population density and urban fabric land use (0.658) does coincide with suspicious coefficientsin the linear regression models (positive coefficient for pop density and a very large negative coeff for LU UF).
# Therefore, we will drop urban fabric land use, for more reliable regression coefficient estimates.
#
# VIF for pop density than drops from 2.38 to 1.65.

# %%
# we drop LU Urb Fab from this model. Similar for DE, other
X.drop(columns=['LU_UrbFab_res'],inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
#                 Feature         VIF
# 0                 const  216.650848
# 1                HHSize    1.028034
# 2                   Sex    1.001762
# 3                   Age    1.013341
# 4     UrbPopDensity_res    1.653727
# 5   UrbBuildDensity_res    1.246587
# 6     DistSubcenter_res    1.272258
# 7        DistCenter_res    1.594677
# 8   IntersecDensity_res    2.712061
# 9     street_length_res    2.069157
# 10          LU_Comm_res    1.148918
# <style type="text/css">
# #T_1b6d0_row0_col0, #T_1b6d0_row1_col1, #T_1b6d0_row2_col2, #T_1b6d0_row3_col3, #T_1b6d0_row4_col4, #T_1b6d0_row5_col5, #T_1b6d0_row6_col6, #T_1b6d0_row7_col7, #T_1b6d0_row8_col8, #T_1b6d0_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1b6d0_row0_col1, #T_1b6d0_row0_col2, #T_1b6d0_row3_col0, #T_1b6d0_row3_col5, #T_1b6d0_row3_col9, #T_1b6d0_row6_col4, #T_1b6d0_row7_col6, #T_1b6d0_row7_col8, #T_1b6d0_row8_col3, #T_1b6d0_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1b6d0_row0_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_1b6d0_row0_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_1b6d0_row0_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_1b6d0_row0_col6 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_1b6d0_row0_col7, #T_1b6d0_row9_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_1b6d0_row0_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_1b6d0_row0_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_1b6d0_row1_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_1b6d0_row1_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_1b6d0_row1_col3, #T_1b6d0_row1_col6, #T_1b6d0_row2_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_1b6d0_row1_col4, #T_1b6d0_row8_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_1b6d0_row1_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_1b6d0_row1_col7, #T_1b6d0_row1_col8, #T_1b6d0_row4_col8 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_1b6d0_row1_col9 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_1b6d0_row2_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_1b6d0_row2_col1, #T_1b6d0_row3_col1, #T_1b6d0_row5_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_1b6d0_row2_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_1b6d0_row2_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_1b6d0_row2_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_1b6d0_row2_col7, #T_1b6d0_row2_col8 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_1b6d0_row2_col9, #T_1b6d0_row3_col8 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_1b6d0_row3_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_1b6d0_row3_col4, #T_1b6d0_row4_col7, #T_1b6d0_row5_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_1b6d0_row3_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_1b6d0_row3_col7 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_1b6d0_row4_col0, #T_1b6d0_row5_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1b6d0_row4_col1, #T_1b6d0_row7_col1, #T_1b6d0_row8_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_1b6d0_row4_col2, #T_1b6d0_row5_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_1b6d0_row4_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_1b6d0_row4_col5, #T_1b6d0_row7_col2, #T_1b6d0_row8_col2, #T_1b6d0_row9_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_1b6d0_row4_col6, #T_1b6d0_row7_col9, #T_1b6d0_row9_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T
level0_col8" class="col_heading level0 col8" >street_length_res</th>
#       <th id="T_4ad01_level0_col9" class="col_heading level0 col9" >LU_UrbFab_res</th>
#       <th id="T_4ad01_level0_col10" class="col_heading level0 col10" >LU_Comm_res</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ad01_level0_row0" class="row_heading level0 row0" >HHSize</th>
#       <td id="T_4ad01_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_4ad01_row0_col1" class="data row0 col1" >-0.125</td>
#       <td id="T_4ad01_row0_col2" class="data row0 col2" >-0.000</td>
#       <td id="T_4ad01_row0_col3" class="data row0 col3" >-0.164</td>
#       <td id="T_4ad01_row0_col4" class="d

# %% [markdown]
# Vienna has several problematic correlations, the highest VIF is for intersection density, which has corr of 0.9 with street lenght. LU urban fabric also has high VIF and correlation with pop density.
# After dropping intersection density and LU urban fabric VIFs are much lower, distance to center remains somewhat high at 4.0, but acceptable.
# Correlation is high (0.743) between population density and distance to center, but we keep both features due to their importance.

# %%
X.drop(columns=['IntersecDensity_res','LU_UrbFab_res'],inplace=True)
X = X[X.columns.drop(list(X.filter(regex='Occupation')))]
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
#                Feature         VIF
# 0                const  112.804796
# 1               HHSize    1.061433
# 2                  Sex    1.022084
# 3                  Age    1.015182
# 4    UrbPopDensity_res    3.381877
# 5  UrbBuildDensity_res    2.679027
# 6    DistSubcenter_res    1.702374
# 7       DistCenter_res    4.022401
# 8    street_length_res    2.116933
# 9          LU_Comm_res    1.636831
# <style type="text/css">
# #T_d9b1f_row0_col0, #T_d9b1f_row1_col1, #T_d9b1f_row2_col2, #T_d9b1f_row3_col3, #T_d9b1f_row4_col4, #T_d9b1f_row5_col5, #T_d9b1f_row6_col6, #T_d9b1f_row7_col7, #T_d9b1f_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d9b1f_row0_col1, #T_d9b1f_row3_col0, #T_d9b1f_row3_col2, #T_d9b1f_row3_col6, #T_d9b1f_row3_col7, #T_d9b1f_row4_col5, #T_d9b1f_row5_col8, #T_d9b1f_row6_col3, #T_d9b1f_row6_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d9b1f_row0_col2, #T_d9b1f_row1_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d9b1f_row0_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_d9b1f_row0_col4, #T_d9b1f_row5_col3 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_d9b1f_row0_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_d9b1f_row0_col6 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_d9b1f_row0_col7 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_d9b1f_row0_col8, #T_d9b1f_row7_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_d9b1f_row1_col0, #T_d9b1f_row4_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_d9b1f_row1_col3, #T_d9b1f_row8_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_d9b1f_row1_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_d9b1f_row1_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_d9b1f_row1_col6, #T_d9b1f_row1_col7 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_d9b1f_row1_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_d9b1f_row2_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_d9b1f_row2_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_d9b1f_row2_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_d9b1f_row2_col4, #T_d9b1f_row7_col8 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_d9b1f_row2_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d9b1f_row2_col6 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_d9b1f_row2_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_d9b1f_row2_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_d9b1f_row3_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_d9b1f_row3_col4 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_d9b1f_row3_col5, #T_d9b1f_row7_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d9b1f_row3_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_d9b1f_row4_col0, #T_d9b1f_row4_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d9b1f_row4_col1, #T_d9b1f_row5_col2, #T_d9b1f_row7_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_d9b1f_row4_col3 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_d9b1f_row4_col7 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_d9b1f_row4_col8 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_d9b1f_row5_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_d9b1f_row5_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d9b1f_row5_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_d9b1f_row5_col6 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_d9b1f_row5_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_d9b1f_row6_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_d9b1f_row6_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_d9b1f_row6_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_d9b1f_row6_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_d9b1f_row6_col7 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_d9b1f_row6_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_d9b1f_row7_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_d9b1f_row7_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d9b1f_row7_col5 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_d9b1f_row7_col6 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_d9b1f_row8_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_d9b1f_row8_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_d9b1f_row8_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_d9b1f_row8_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_d9b1f_row8_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d9b1f_row8_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_d9b1f_row8_col7 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# </style>
# <table id="T_d9b1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9b1f_level0_col0" class="col_heading level0 col0" >HHSize</th>
#       <th id="T_d9b1f_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_d9b1f_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_d9b1f_level0_col3" class="col_heading level0 col3" >UrbPopDensity_res</th>
#       <th id="T_d9b1f_level0_col4" class="col_heading level0 col4" >UrbBuildDensity_res</th>
#       <th id="T_d9b1f_level0_col5" class="col_heading level0 col5" >DistSubcenter_res</th>
#       <th id="T_d9b1f_level0_col6" class="col_heading level0 col6" >DistCenter_res</th>
#       <th id="T_d9b1f_level0_col7" class="col_heading level0 col7" >street_length_res</th>
#       <th id="T_d9b1f_level0_col8" class="col_heading level0 col8" >LU_Comm_res</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9b1f_level0_row0" class="row_heading level0 row0" >HHSize</th>
#       <td id="T_d9b1f_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_d9b1f_row0_col1" class="data row0 col1" >-0.125</td>
#       <td id="T_d9b1f_row0_col2" class="data row0 col2" >-0.000</td>
#       <td id="T_d9b1f_row0_col3" class="data row0 col3" >-0.164</td>
#       <td id="T_d9b1f_row0_col4" class="data row0 col4" >-0.156</td>
#       <td id="T_d9b1f_row0_col5" class="data row0 col5" >0.013</td>
#       <td id="T_d9b1f_row0_col6" class="data row0 col6" >0.153</td>
#       <td id="T_d9b1f_row0_col7" class="data row0 col7" >0.064</td>
#       <td id="T_d9b1f_row0_col8" class="data row0 col8" >-0.082</td>
#     </tr>
#     <tr>
#       <th id="T_d9b1f_level0_row1" class="row_heading level0 row1" >Sex</th>
#       <td id="T_d9b1f_row1_col0" class="data row1 col0" >-0.125</td>
#       <td id="T_d9b1f_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_d9b1f_row1_col2" class="data row1 col2" >0.003</td>
#       <td id="T_d9b1f_row1_col3" class="data row1 col3" >-0.011</td>
#       <td id="T_d9b1f_row1_col4" class="data row1 col4" >-0.006</td>
#       <td id="T_d9b1f_row1_col5" class="data row1 col5" >-0.001</td>
#       <td id="T_d9b1f_row1_col6" class="data row1 col6" >-0.022</td>
#       <td id="T_d9b1f_row1_col7" class="data row1 col7" >0.017</td>
#       <td id="T_d9b1f_row1_col8" class="data row1 col8" >0.048</td>
#     </tr>
#     <tr>
#       <th id="T_d9b1f_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_d9b1f_row2_col0" class="data row2 col0" >-0.000</td>
#       <td id="T_d9b1f_row2_col1" class="data row2 col1" >0.003</td>
#       <td id="T_d9b1f_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_d9b1f_row2_col3" class="data row2 col3" >-0.090</td>
#       <td id="T_d9b1f_row2_col4" class="data row2 col4" >-0.085</td>
#       <td id="T_d9b1f_row2_col5" class="data row2 col5" >0.027</td>
#       <td id="T_d9b1f_row2_col6" class="data row2 col6" >0.087</td>
#       <td id="T_d9b1f_row2_col7" class="data row2 col7" >0.027</td>
#       <td id="T_d9b1f_row2_col8" class="data row2 col8" >-0.066</td>
#     </tr>
#     <tr>
#       <th id="T_d9b1f_level0_row3" class="row_heading level0 row3" >UrbPopDensity_res</th>
#       <td id="T_d9b1f_row3_col0" class="data row3 col0" >-0.164</td>
#       <td id="T_d9b1f_row3_col1" class="data row3 col1" >-0.011</td>
#       <td id="T_d9b1f_row3_col2" class="data row3 col2" >-0.090</td>
#       <td id="T_d9b1f_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_d9b1f_row3_col4" class="data row3 col4" >0.619</td>
#       <td id="T_d9b1f_row3_col5" class="data row3 col5" >-0.197</td>
#       <td id="T_d9b1f_row3_col6" class="data row3 col6" >-0.743</td>
#       <td id="T_d9b1f_row3_col7" clas

# %%
X=vif_corr('Germany_other')
X_disp=[re.sub('FeatureD_','', x) for x in X.columns]
X.columns=X_disp
X = X[X.columns.drop(list(X.filter(regex='Education')))]
X = X[X.columns.drop(list(X.filter(regex='Season')))]
X = X[X.columns.drop(list(X.filter(regex='Trip_Time')))]
X = X[X.columns.drop(list(X.filter(regex='Occupation')))]
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Germany_other Germany
# Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
>LU_Comm_res</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_765d5_level0_row0" class="row_heading level0 row0" >HHSize</th>
#       <td id="T_765d5_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_765d5_row0_col1" class="data row0 col1" >-0.072</td>
#       <td id="T_765d5_row0_col2" class="data row0 col2" >-0.109</td>
#       <td id="T_765d5_row0_col3" class="data row0 col3" >-0.105</td>
#       <td id="T_765d5_row0_col4" class="data row0 col4" >-0.108</td>
#       <td id="T_765d5_row0_col5" class="data row0 col5" >0.031</td>
#       <td id="T_765d5_row0_col6" class="data row0 col6" >0.117</td>
#       <td id="T_765d5_row0_col7" class="data row0 col7" >-0.104</td>
#       <td id="T_765d5_row0_col8" class="data row0 col8" >0.049</td>
#       <td id="T_765d5_row0_col9" class="data row0 col9" >-0.075</td>
#       <td id="T_765d5_row0_col10" class="data row0 col10" >-0.078</td>
#     </tr>

# %% [markdown]
# VIFs are acceptable low for rest of Germany. Some high correlation between urban fabric land use with pop density (0.772) and intersection density (0.739). Intersection density also quite highly correlated with street length and population density.
#
# Dropping urban fabric land use and intersection density leads to all very low VIFs and correlations.

# %%
X.drop(columns=['LU_UrbFab_res','IntersecDensity_res'],inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
#                Feature         VIF
# 0                const  101.048895
# 1               HHSize    1.046360
# 2                  Sex    1.005740
# 3                  Age    1.041378
# 4    UrbPopDensity_res    1.790977
# 5  UrbBuildDensity_res    1.985419
# 6    DistSubcenter_res    1.198307
# 7       DistCenter_res    1.335819
# 8    street_length_res    1.404958
# 9          LU_Comm_res    1.459573
# <style type="text/css">
# #T_9a53f_row0_col0, #T_9a53f_row1_col1, #T_9a53f_row2_col2, #T_9a53f_row3_col3, #T_9a53f_row4_col4, #T_9a53f_row5_col5, #T_9a53f_row6_col6, #T_9a53f_row7_col7, #T_9a53f_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9a53f_row0_col1, #T_9a53f_row0_col2, #T_9a53f_row2_col0, #T_9a53f_row3_col0, #T_9a53f_row3_col6, #T_9a53f_row3_col7, #T_9a53f_row4_col0, #T_9a53f_row4_col5, #T_9a53f_row5_col8, #T_9a53f_row6_col4, #T_9a53f_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9a53f_row0_col3, #T_9a53f_row1_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_9a53f_row0_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_9a53f_row0_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_9a53f_row0_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_9a53f_row0_col7, #T_9a53f_row2_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_9a53f_row0_col8, #T_9a53f_row2_col8, #T_9a53f_row7_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_9a53f_row1_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_9a53f_row1_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_9a53f_row1_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_9a53f_row1_col5, #T_9a53f_row2_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_9a53f_row1_col6, #T_9a53f_row8_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_9a53f_row1_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_9a53f_row1_col8, #T_9a53f_row2_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_9a53f_row2_col1, #T_9a53f_row6_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_9a53f_row2_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_9a53f_row2_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_9a53f_row3_col1, #T_9a53f_row4_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_9a53f_row3_col2, #T_9a53f_row5_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_9a53f_row3_col4, #T_9a53f_row4_col8 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_9a53f_row3_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_9a53f_row3_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_9a53f_row4_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_9a53f_row4_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_9a53f_row4_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_9a53f_row4_col7, #T_9a53f_row7_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_9a53f_row5_col0, #T_9a53f_row8_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_9a53f_row5_col1, #T_9a53f_row6_col1, #T_9a53f_row8_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_9a53f_row5_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_9a53f_row5_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_9a53f_row5_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_9a53f_row5_col7 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_9a53f_row6_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_9a53f_row6_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_9a53f_row6_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_9a53f_row6_col7 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_9a53f_row6_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_
X_disp=[re.sub('FeatureD_','', x) for x in X.columns]
X.columns=X_disp
X = X[X.columns.drop(list(X.filter(regex='Education')))]
X = X[X.columns.drop(list(X.filter(regex='Season')))]
X = X[X.columns.drop(list(X.filter(regex='Trip_Time')))]
X = X[X.columns.drop(list(X.filter(regex='Occupation')))]
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# France_other France
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 Feature         VIF
# 0                 const  118.898692
# 1                HHSize    1.055082
# 2                   Sex    1.009441
# 3                   Age    1.032519
# 4     UrbPopDensity_res    3.345826
# 5   UrbBuildDensity_res    2.868368
# 6     DistSubcenter_res    1.535069
# 7        DistCenter_res    1.838679
# 8   IntersecDensity_res    4.004131
# 9     street_length_res    1.839450
# 10        LU_UrbFab_res    1.959435
# 11          LU_Comm_res    1.381690
# <style type="text/css">
# #T_062d0_row0_col0, #T_062d0_row1_col1, #T_062d0_row2_col2, #T_062d0_row3_col3, #T_062d0_row4_col4, #T_062d0_row5_col5, #T_062d0_row6_col6, #T_062d0_row7_col7, #T_062d0_row8_col8, #T_062d0_row9_col9, #T_062d0_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_062d0_row0_col1, #T_062d0_row4_col2, #T_062d0_row5_col10, #T_062d0_row6_col3, #T_062d0_row6_col4, #T_062d0_row6_col9, #T_062d0_row7_col0, #T_062d0_row7_col5, #T_062d0_row7_col6, #T_062d0_row7_col8, #T_062d0_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_062d0_row0_col2, #T_062d0_row3_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_062d0_row0_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_062d0_row0_col4, #T_062d0_row2_col9 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_062d0_row0_col5, #T_062d0_row1_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_062d0_row0_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_062d0_row0_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_062d0_row0_col8 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_062d0_row0_col9, #T_062d0_row3_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_062d0_row0_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_062d0_row1_col0, #T_062d0_row9_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_062d0_row1_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_062d0_row1_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_062d0_row1_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_062d0_row1_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_062d0_row1_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_062d0_row1_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_062d0_row1_col9 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_062d0_row1_col10, #T_062d0_row6_col2, #T_062d0_row9_col8 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_062d0_row2_col0, #T_062d0_row2_col10 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_062d0_row2_col1, #T_062d0_row8_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_062d0_row2_col3, #T_062d0_row4_col8, #T_062d0_row5_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_062d0_row2_col4, #T_062d0_row3_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_062d0_row2_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_062d0_row2_col6 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_062d0_row2_col7, #T_062d0_row6_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_062d0_row2_col8, #T_062d0_row4_col10 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_062d0_row3_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_062d0_row3_col1, #T_062d0_row6_col1, #T_062d0_row10_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_062d0_row3_col2, #T_062d0_row8_col9, #T_062d0_row9_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_062d0_row3_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_062d0_row3_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_062d0_row3_col7 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_062d0_row3_col9 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_062d0_row4_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_062d0_row4_col1, #T_062d0_row6_col10 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_062d0_row4_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_062d0_row4_col5, #T_062d0_row10_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_062d0_row4_col6, #T_062d0_row8_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_062d0_row4_col7 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_062d0_row4_col9 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_062d0_row5_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_062d0_row5_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_062d0_row5_col3, #T_062d0_row5_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_062d0_row5_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_062d0_row5_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_062d0_row5_col8 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_062d0_row5_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_062d0_row6_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_062d0_row6_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_062d0_row6_col8 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_062d0_row7_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_062d0_row7_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_062d0_row7_col3 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_062d0_row7_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_062d0_row7_col9 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_062d0_row7_col10 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_062d0_row8_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_062d0_row8_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_062d0_row8_col2, #T_062d0_row9_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_062d0_row8_col5 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_062d0_row8_col6 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_062d0_row8_col10, #T_062d0_row9_col5, #T_062d0_row10_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_062d0_row9_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_062d0_row9_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_062d0_row9_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_062d0_row9_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_062d0_row9_col7 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_062d0_row10_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_062d0_row10_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_062d0_row10_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_062d0_row10_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_062d0_row10_col7 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_062d0_row10_col8 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_062d0_row10_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_062d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_062d0_level0_col0" class="col_heading level0 col0" >HHSize</th>
#       <th id="T_062d0_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_062d0_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_062d0_level0_col3" class="col_heading level0 col3" >UrbPopDensity_res</th>
#       <th id="T_062d0_level0_col4" class="col_heading level0 col4" >UrbBuildDensity_res</th>
#       <th id="T_062d0_level0_col5" class="col_heading level0 col5" >DistSubcenter_res</th>
#       <th id="T_062d0_level0_col6" class="col_heading level0 col6" >DistCenter_res</th>
#       <th id="T_062d0_level0_col7" class="col_heading level0 col7" >IntersecDensity_res</th>
#       <th id="T_062d0_level0_col8" class="col_heading level0 col8" >street_length_res</th>
#       <th id="T_062d0_level0_col9" class="col_heading level0 col9" >LU_UrbFab_res</th>
#       <th id="T_062d0_level0_col10" class="col_heading level0 col10" >LU_Comm_res</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_062d0_level0_row0" class="row_heading level0 row0" >HHSize</th>
#       <td id="T_062d0_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_062d0_row0_col1" class="data row0 col1" >-0.076</td>
#       <td id="T_062d0_row0_col2" class="data row0 col2" >-0.019</td>
#       <td id="T_062d0_row0_col3" class="data row0 col3" >-0.136</td>
#       <td id="T_062d0_row0_col4" class="data row0 col4" >-0.140</td>
#       <td id="T_062d0_row0_col5" class="data row0 col5" >0.097</td>
#       <td id="T_062d0_row0_col6" class="data row0 col6" >0.194</td>
#       <td id="T_062d0_row0_col7" class="data row0 col7" >-0.176</td>
#       <td id="T_0

# %% [markdown]
# Rest of France has acceptably low VIFs and correlations, highest VIF is 4.0 for intersection density, which has moderatly high correlation with population density.
# Dropping intersection density would also improve comparability between rest of France and rest of Germany, and would maintain consistency between dist agg and dist commute models for rest of France.

# %%
X.drop(columns=['IntersecDensity_res'],inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
#                 Feature        VIF
# 0                 const  72.721763
# 1                HHSize   1.053835
# 2                   Sex   1.009433
# 3                   Age   1.032183
# 4     UrbPopDensity_res   3.233387
# 5   UrbBuildDensity_res   2.624639
# 6     DistSubcenter_res   1.526662
# 7        DistCenter_res   1.667172
# 8     street_length_res   1.282810
# 9         LU_UrbFab_res   1.818256
# 10          LU_Comm_res   1.380271
# <style type="text/css">
# #T_19957_row0_col0, #T_19957_row1_col1, #T_19957_row2_col2, #T_19957_row3_col3, #T_19957_row4_col4, #T_19957_row5_col5, #T_19957_row6_col6, #T_19957_row7_col7, #T_19957_row8_col8, #T_19957_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_19957_row0_col1, #T_19957_row3_col0, #T_19957_row3_col5, #T_19957_row3_col6, #T_19957_row4_col0, #T_19957_row4_col2, #T_19957_row4_col5, #T_19957_row5_col9, #T_19957_row6_col3, #T_19957_row6_col4, #T_19957_row6_col8, #T_19957_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_19957_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_19957_row0_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_19957_row0_col4, #T_19957_row2_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_19957_row0_col5, #T_19957_row0_col7 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_19957_row0_col6 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_19957_row0_col8, #T_19957_row3_col9, #T_19957_row9_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_19957_row0_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_19957_row1_col0, #T_19957_row4_col1, #T_19957_row6_col9, #T_19957_row9_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_19957_row1_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_19957_row1_col3, #T_19957_row1_col6, #T_19957_row2_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_19957_row1_col4, #T_19957_row2_col7, #T_19957_row6_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_19957_row1_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_19957_row1_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_19957_row1_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_19957_row1_col9, #T_19957_row6_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_19957_row2_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_19957_row2_col1, #T_19957_row7_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_19957_row2_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_19957_row2_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_19957_row2_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_19957_row2_col9 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_19957_row3_col1, #T_19957_row6_col1, #T_19957_row9_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_19957_row3_col2, #T_19957_row7_col8, #T_19957_row8_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_19957_row3_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_19957_row3_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_19957_row3_col8 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_19957_row4_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_19957_row4_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_19957_row4_col7, #T_19957_row9_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_19957_row4_col8 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_19957_row4_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_19957_row5_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_19957_row5_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_19957_row5_col2, #T_19957_row9_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_19957_row5_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_19957_row5_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_19957_row5_col6 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_19957_row5_col7 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_19957_row5_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_19957_row6_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_19957_row6_col7 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_19957_row7_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_19957_row7_col1, #T_19957_row8_col0, #T_19957_row8_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_19957_row7_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_19957_row7_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_19957_row7_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_19957_row7_col6 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_19957_row7_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_19957_row8_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_19957_row8_col2, #T_19957_row9_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_19957_row8_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_19957_row8_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_19957_row8_col6 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_19957_row9_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_19957_row9_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_19957_row9_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_19957">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19957_level0_col0" class="col_heading level0 col0" >HHSize</th>
#       <th id="T_19957_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_19957_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_19957_level0_col3" class="col_heading level0 col3" >UrbPopDensity_res</th>
#       <th id="T_19957_level0_col4" class="col_heading level0 col4" >UrbBuildDensity_res</th>
#       <th id="T_19957_level0_col5" class="col_heading level0 col5" >DistSubcenter_res</th>
#       <th id="T_19957_level0_col6" class="col_heading level0 col6" >DistCenter_res</th>
#       <th id="T_19957_level0_col7" class="col_heading level0 col7" >street_length_res</th>
#       <th id="T_19957_level0_col8" class="col_heading level0 col8" >LU_UrbFab_res</th>
#       <th id="T_19957_level0_col9" class="col_heading level0 col9" >LU_Comm_res</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19957_level0_row0" class="row_heading level0 row0" >HHSize</th>
#       <td id="T_19957_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_19957_row0_col1" class="data row0 col1" >-0.076</td>
#       <td id="T_19957_row0_col2" class="data row0 col2" >-0.019</td>
#       <td id="T_19957_row0_col3" class="data row0 col3" >-0.136</td>
#       <td id="T_19957_row0_col4" class="data row0 col4" >-0.140</td>
#       <td id="T_19957_row0_col5" class="data row0 col5" >0.097</td>
#       <td id="T_19957_row0_col6" class="data row0 col6" >0.194</td>
#       <td id="T_19957_row0_col7" class="data row0 col7" >0.111</td>
#       <td id="T_19957_row0_col8" class="data row0 col8" >-0.078</td>
#       <td id="T_19957_row0_col9" class="data row0 col9" >-0.058</td>
#     </tr>
#     <tr>
#       <th id="T_19957_level0_row1" class="row_heading level0 row1" >Sex</th>
#       <td id="T_19957_row1_col0" class="data row1 col0" >-0.076</td>
#       <td id="T_19957_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_19957_row1_col2" class="data row1 col2" >0.053</td>
#       <td id="T_19957_row1_col3" class="data row1 col3" >-0.011</td>
#       <td id="T_19957_row1_col4" class="data row1 col4" >-0.014</td>
#       <td id="T_19957_row1_col5" class="data row1 col5" >-0.003</td>
#       <td id="T_19957_row1_col6" class="data row1 col6" >-0.013</td>
#       <td id="T_19957_row1_col7" class="data row1 col7" >-0.019</td>
#       <td id="T_19957_row1_col8" class="data row1 col8" >0.010</td>
#       <td id="T_19957_row1_col9" class="data row1 col9" >-0.012</td>
#     </tr>
#     <tr>
#       <th id="T_19957_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_19957_row2_col0" class="data row2 col0" >-0.019</td>
#       <td id="T_19957_row2_col1" class="data row2 col1" >0.053</td>
#       <td id="T_19957_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_19957_row2_col3" class="data row2 col3" >-0.129</td>
#       <td id="T_19957_row2_col4" class="data row2 col4" >-0.135</td>
#       <td id="T_19957_row2_col5" class="data row2 col5" >0.080</td>
#       <td id="T_19957_row2_

# %%
# all city model
city='Berlin'
country=countries[cities_all.index(city)]
print(city, country)

city0='Berlin'
df0=pd.read_csv('../outputs/Combined/' + city0 + '_UF.csv')
# add to make consistent with definition of apprenticeship within Education in other countries
df0.loc[(df0['Training'].isin(['Apprenticeship/Business','Craftsman/Technical'])) & (df0['Education']!='University'),'Education']='Apprenticeship'
df0=df0.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
            'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
            'Sex', 'Occupation', 'Education','Age',
            #'PopDensity_res','BuildDensity_res',
            'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
            'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
            'LU_Comm_res' ,'Trip_Distance']]
df0['City']=city0
df0['Country']='Germany'
df_all=df0.copy()

cities0=['Dresden', 'Leipzig','Magdeburg','Potsdam','Frankfurt am Main','Düsseldorf','Kassel']
for city1 in cities0:
        print(city1)
        df1=pd.read_csv('../outputs/Combined/' + city1 + '_UF.csv')
        df1.loc[(df1['Training'].isin(['Apprenticeship/Business','Craftsman/Technical'])) & (df0['Education']!='University'),'Education']='Apprenticeship'
        df1=df1.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
                    'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
                    'Sex', 'Occupation', 'Education','Age',
                    #'PopDensity_res','BuildDensity_res',
                    'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
                    'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                    'LU_Comm_res','Trip_Distance']]
        df1['City']=city1
        df1['Country']='Germany'
        if len(df1.columns==df_all.columns):
                df_all=pd.concat([df_all,df1])
                print(city1, 'added.')
                #print(len(df_all), 'rows in the combined dataframe')
df_all['HHNR']=df_all['City']+'_'+df_all['HHNR'].astype(int).astype(str)
df_all['HH_PNR']=df_all['City']+'_'+df_all['HH_PNR'].astype(int).astype(str)
df_all['HH_P_WNR']=df_all['City']+'_'+df_all['HH_P_WNR'].astype(str)
df_all.drop(columns='City',inplace=True)
df_DE=df_all.copy()
city0='Clermont'
df0=pd.read_csv('../outputs/Combined/' + city0 + '_UF.csv')
df0=df0.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
            'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
            'Sex', 'Occupation', 'Education','Age',
            #'PopDensity_res','BuildDensity_res',
            'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
            'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
            'LU_Comm_res', 'Trip_Distance']]
df0['City']=city0
df0['Country']='France'
df_all=df0.copy()

cities0=['Toulouse','Montpellier','Lyon','Nantes','Nimes','Lille','Dijon','Paris']
for city1 in cities0:
        print(city1)
        df1=pd.read_csv('../outputs/Combined/' + city1 + '_UF.csv')
        df1=df1.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
                    'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
                    'Sex', 'Occupation', 'Education','Age',
                    #'PopDensity_res','BuildDensity_res',
                    'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
                    'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                    'LU_Comm_res', 'Trip_Distance']]
        df1['City']=city1
        df1['Country']='France'
        if len(df1.columns==df_all.columns):
                df_all=pd.concat([df_all,df1])
                print(city1, 'added.')
                #print(len(df_all), 'rows in the combined dataframe')
df_all['HHNR']=df_all['City']+'_'+df_all['HHNR'].astype(str)
df_all['HH_PNR']=df_all['City']+'_'+df_all['HH_PNR'].astype(str)
df_all['HH_P_WNR']=df_all['City']+'_'+df_all['HH_P_WNR'].astype(str)
df_all.drop(columns='City',inplace=True)
df_FR=df_all.copy()
df=pd.read_csv('../outputs/Combined/' + 'Madrid' + '_UF.csv',dtype={'Ori_geocode': str, 'Des_geocode': str,'Res_geocode': str })
df_UF=df.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
                'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
                'Sex', 'Occupation', 'Education','Age',
                #'PopDensity_res','BuildDensity_res',
                'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
                'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                'LU_Comm_res', 'Trip_Distance']]
df_UF['City']='Madrid'
df_UF['Country']='Spain'
df_UF['HHNR']=df_UF['City']+'_'+df_UF['HHNR'].astype(str)
df_UF['HH_PNR']=df_UF['City']+'_'+df_UF['HH_PNR'].astype(str)
df_UF['HH_P_WNR']=df_UF['City']+'_'+df_UF['HH_P_WNR'].astype(str)
df_UF.drop(columns='City',inplace=True)
df_Madrid=df_UF.copy()
df=pd.read_csv('../outputs/Combined/' + 'Wien' + '_UF.csv',dtype={'Ori_geocode': str, 'Des_geocode': str,'Res_geocode': str })
df_UF=df.loc[:,['HH_P_WNR','HH_PNR', 'HHNR','Ori_geocode', 'Des_geocode','Res_geocode', 
                'Trip_Time', 'Season','Trip_Purpose_Agg','HHSize',
                'Sex', 'Occupation', 'Education','Age',
                #'PopDensity_res','BuildDensity_res',
                'UrbPopDensity_res', 'UrbBuildDensity_res','DistSubcenter_res', 'DistCenter_res',
                'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                'LU_Comm_res', 'Trip_Distance']]
df_UF['City']='Wien'
df_UF['Country']='Austria'
df_UF['HHNR']=df_UF['City']+'_'+df_UF['HHNR'].astype(str)
df_UF['HH_PNR']=df_UF['City']+'_'+df_UF['HH_PNR'].astype(str)
df_UF['HH_P_WNR']=df_UF['City']+'_'+df_UF['HH_P_WNR'].astype(str)
df_UF.drop(columns='City',inplace=True)
df_Wien=df_UF.copy()
df_UF=pd.concat([df_DE,df_FR,df_Madrid,df_Wien],ignore_index=True)
df_UF['Trip_Purpose_Agg'].value_counts()
# Out:
# Berlin Germany
# Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
# Dresden
# Dresden added.
# Leipzig
# Leipzig added.
# Magdeburg
# Magdeburg added.
# Potsdam
# Potsdam added.
# Frankfurt am Main
# Frankfurt am Main added.
# Düsseldorf
# Düsseldorf added.
# Kassel
# Kassel added.
# Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
# Toulouse
# Toulouse added.
# Montpellier
# Montpellier added.
# Lyon
# Lyon added.
# Nantes
# Nantes added.
# Nimes
# Nimes added.
# Lille
# Lille added.
# Dijon
# Dijon added.
# Paris
# Paris added.
# Home↔Leisure      156611
# Other             132906
# Home↔Work         130623
# Home↔Shopping     108008
# Home↔School        83984
# Home↔Companion     62002
# Name: Trip_Purpose_Agg, dtype: int64

# %%
df_UF=pd.concat([df_DE,df_FR,df_Madrid,df_Wien],ignore_index=True)
df_UF=df_UF.loc[df_UF['Trip_Purpose_Agg']=='Home↔Work',]
df_UF.drop(columns='Trip_Purpose_Agg',inplace=True)

Occ_dict={'Employed_FullTime':'Employed','Employed_PartTime':'Employed','Employed':'Employed','Trainee':'Employed',
          'Student_School':'Student_School','Student_3rdLevel':'Student_3rdLevel','Pre-School':'Pre-School','Retired':'Retired',
          'Unemployed':'Unemployed/Other','Other':'Unemployed/Other','Home_Partner':'Unemployed/Other'}
Edu_dict={'University':'University','Secondary':'Secondary','Secondary+BAC':'Secondary','Secondary+Matura':'Secondary',
          'Apprenticeship':'Apprenticeship',
          'Elementary':'Primary/None','Pre-School':'Primary/None','No diploma yet':'Primary/None','Unknown':'Primary/None','Other':'Primary/None'}

df_UF['Occupation']=df_UF['Occupation'].map(Occ_dict)
df_UF['Education']=df_UF['Education'].map(Edu_dict)

df_UF=pd.concat([df_UF.drop(columns='Trip_Distance'),df_UF['Trip_Distance']],axis=1)

df=df_UF.dropna()
df['Sex']=df['Sex']-1 # change from [1,2] to [0,1], for plotting purposes
df=df.loc[df['UrbBuildDensity_res']<1e8,]   # remove high building density outliers (For Leipzig)

# identify the feature columns
N_non_feature=6 # how many non-features are at the start of the df
cols=df.columns
newcols=(df.columns[:N_non_feature].tolist()) + ('FeatureD' +'_'+ cols[N_non_feature:-1]).tolist() + (df.columns[-1:].tolist())
# change column names
df.set_axis(newcols,axis=1,inplace=True)
df = df.reset_index(drop=True)
df0=df.copy()

# convert  all categorical variables to dummies
df_Cat=df.select_dtypes('object')[[col for col in df.select_dtypes('object').columns if "FeatureD" in col]]
for col in df_Cat:
    dum=pd.get_dummies(df[[col]])
    df = pd.concat([df, dum], axis = 1)
    # remove the original categorical columns
df.drop(df_Cat.columns.tolist(),axis=1,inplace=True)

X=df[[col for col in df.columns if "FeatureD" in col]]
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# No VIF or correlation concerns with all cities. Built-up and population density have high correlation (0.697) but VIFs are fine.

# %%
# no correlation concerns
X_disp=[re.sub('FeatureD_','', x) for x in X.columns]
X.columns=X_disp
X = X[X.columns.drop(list(X.filter(regex='Education')))]
X = X[X.columns.drop(list(X.filter(regex='Season')))]
X = X[X.columns.drop(list(X.filter(regex='Trip_Time')))]
X = X[X.columns.drop(list(X.filter(regex='Occupation')))]
X = X[X.columns.drop(list(X.filter(regex='Country')))]
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
#                 Feature        VIF
# 0                 const  72.721763
# 1                HHSize   1.053835
# 2                   Sex   1.009433
# 3                   Age   1.032183
# 4     UrbPopDensity_res   3.233387
# 5   UrbBuildDensity_res   2.624639
# 6     DistSubcenter_res   1.526662
# 7        DistCenter_res   1.667172
# 8     street_length_res   1.282810
# 9         LU_UrbFab_res   1.818256
# 10          LU_Comm_res   1.380271
# <style type="text/css">
# #T_e94be_row0_col0, #T_e94be_row1_col1, #T_e94be_row2_col2, #T_e94be_row3_col3, #T_e94be_row4_col4, #T_e94be_row5_col5, #T_e94be_row6_col6, #T_e94be_row7_col7, #T_e94be_row8_col8, #T_e94be_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e94be_row0_col1, #T_e94be_row3_col0, #T_e94be_row3_col5, #T_e94be_row3_col6, #T_e94be_row4_col0, #T_e94be_row4_col2, #T_e94be_row4_col5, #T_e94be_row5_col9, #T_e94be_row6_col3, #T_e94be_row6_col4, #T_e94be_row6_col8, #T_e94be_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e94be_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e94be_row0_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e94be_row0_col4, #T_e94be_row2_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_e94be_row0_col5, #T_e94be_row0_col7 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_e94be_row0_col6 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_e94be_row0_col8, #T_e94be_row3_col9, #T_e94be_row9_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e94be_row0_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e94be_row1_col0, #T_e94be_row4_col1, #T_e94be_row6_col9, #T_e94be_row9_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e94be_row1_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e94be_row1_col3, #T_e94be_row1_col6, #T_e94be_row2_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_e94be_row1_col4, #T_e94be_row2_col7, #T_e94be_row6_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_e94be_row1_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e94be_row1_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e94be_row1_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e94be_row1_col9, #T_e94be_row6_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_e94be_row2_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_e94be_row2_col1, #T_e94be_row7_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e94be_row2_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e94be_row2_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_e94be_row2_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_e94be_row2_col9 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e94be_row3_col1, #T_e94be_row6_col1, #T_e94be_row9_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e94be_row3_col2, #T_e94be_row7_col8, #T_e94be_row8_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e94be_row3_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_e94be_row3_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e94be_row3_col8 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_e94be_row4_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_e94be_row4_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e94be_row4_col7, #T_e94be_row9_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e94be_row4_col8 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_e94be_row4_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_e94be_row5_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e94be_row5_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e94be_row5_col2, #T_e94be_row9_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e94be_row5_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e94be_row5_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e94be_row5_col6 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_e94be_row5_col7 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_e94be_row5_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e94be_row6_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_e94be_row6_col7 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_e94be_row7_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e94be_row7_col1, #T_e94be_row8_col0, #T_e94be_row8_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e94be_row7_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_e94be_row7_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e94be_row7_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_e94be_row7_col6 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_e94be_row7_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e94be_row8_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e94be_row8_col2, #T_e94be_row9_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e94be_row8_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_e94be_row8_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_e94be_row8_col6 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_e94be_row9_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_e94be_row9_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_e94be_row9_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e94be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e94be_level0_col0" class="col_heading level0 col0" >HHSize</th>
#       <th id="T_e94be_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_e94be_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_e94be_level0_col3" class="col_heading level0 col3" >UrbPopDensity_res</th>
#       <th id="T_e94be_level0_col4" class="col_heading level0 col4" >UrbBuildDensity_res</th>
#       <th id="T_e94be_level0_col5" class="col_heading level0 col5" >DistSubcenter_res</th>
#       <th id="T_e94be_level0_col6" class="col_heading level0 col6" >DistCenter_res</th>
#       <th id="T_e94be_level0_col7" class="col_heading level0 col7" >street_length_res</th>
#       <th id="T_e94be_level0_col8" class="col_heading level0 col8" >LU_UrbFab_res</th>
#       <th id="T_e94be_level0_col9" class="col_heading level0 col9" >LU_Comm_res</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e94be_level0_row0" class="row_heading level0 row0" >HHSize</th>
#       <td id="T_e94be_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_e94be_row0_col1" class="data row0 col1" >-0.076</td>
#       <td id="T_e94be_row0_col2" class="data row0 col2" >-0.019</td>
#       <td id="T_e94be_row0_col3" class="data row0 col3" >-0.136</td>
#       <td id="T_e94be_row0_col4" class="data row0 col4" >-0.140</td>
#       <td id="T_e94be_row0_col5" class="data row0 col5" >0.097</td>
#       <td id="T_e94be_row0_col6" class="data row0 col6" >0.194</td>
#       <td id="T_e94be_row0_col7" class="data row0 col7" >0.111</td>
#       <td id="T_e94be_row0_col8" class="data row0 col8" >-0.078</td>
#       <td id="T_e94be_row0_col9" class="data row0 col9" >-0.058</td>
#     </tr>
#     <tr>
#       <th id="T_e94be_level0_row1" class="row_heading level0 row1" >Sex</th>
#       <td id="T_e94be_row1_col0" class="data row1 col0" >-0.076</td>
#       <td id="T_e94be_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_e94be_row1_col2" class="data row1 col2" >0.053</td>
#       <td id="T_e94be_row1_col3" class="data row1 col3" >-0.011</td>
#       <td id="T_e94be_row1_col4" class="data row1 col4" >-0.014</td>
#       <td id="T_e94be_row1_col5" class="data row1 col5" >-0.003</td>
#       <td id="T_e94be_row1_col6" class="data row1 col6" >-0.013</td>
#       <td id="T_e94be_row1_col7" class="data row1 col7" >-0.019</td>
#       <td id="T_e94be_row1_col8" class="data row1 col8" >0.010</td>
#       <td id="T_e94be_row1_col9" class="data row1 col9" >-0.012</td>
#     </tr>
#     <tr>
#       <th id="T_e94be_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_e94be_row2_col0" class="data row2 col0" >-0.019</td>
#       <td id="T_e94be_row2_col1" class="data row2 col1" >0.053</td>
#       <td id="T_e94be_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_e94be_row2_col3" class="data row2 col3" >-0.129</td>
#       <td id="T_e94be_row2_col4" class="data row2 col4" >-0.135</td>
#       <td id="T_e94be_row2_col5" class="data row2 col5" >0.080</td>
#       <td id="T_e94be_row2_
