# %% [markdown]
# ## Correlation and Variance Inflation, Trip Distance (agg)

# %% [markdown]
# This is a notebook to compute variance inflation factors and correlation coefficients between urban form and selected other features for models of aggregate trip distance in 19 European cities.
#
# In general, we try to avoid VIF>5, and correlation factors > 0.7 (absolute value)

# %%
# script to model avergage trip distances in all cities
# last update Peter Berrill 20 Nov 2023

# load in required packages
import numpy as np
import pandas as pd
import shap
import re
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, cross_validate, GroupKFold, StratifiedGroupKFold, RepeatedKFold, StratifiedKFold, GridSearchCV, KFold
from sklearn import metrics, linear_model
from xgboost import XGBClassifier, XGBRegressor
import os
import sys
import matplotlib.pyplot as plt
import pickle
import statsmodels.formula.api as smf
from datetime import datetime
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import seaborn as sns

cities_all=['Berlin','Dresden','Düsseldorf','Frankfurt am Main','Kassel','Leipzig','Magdeburg','Potsdam','Clermont','Dijon','Lille','Lyon','Montpellier','Nantes','Nimes','Paris','Toulouse','Madrid','Wien','France_other','Germany_other']
countries=['Germany','Germany','Germany','Germany','Germany','Germany','Germany','Germany','France','France','France','France','France','France','France','France','France','Spain','Austria','France','Germany']
cities_small=['Dresden','Düsseldorf','Frankfurt am Main','Kassel','Leipzig','Magdeburg','Potsdam','Clermont','Dijon','Lille','Lyon','Montpellier','Nantes','Nimes','Toulouse']
cities_main=['Berlin','Paris','Madrid','Wien','Germany_other','France_other']
# Out:
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.

# %%
def vif_corr(city):
    country=countries[cities_all.index(city)]
    print(city, country)
    if city=='Germany_other':
        city0='Dresden'
        df0=pd.read_csv('../outputs/Combined/' + city0 + '_UF.csv')
        df0['Commute_Trip']=0
        df0.loc[df0['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
        df0=df0.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
        #'PopDensity_res','BuildDensity_res', 
        'UrbPopDensity_res', 'UrbBuildDensity_res',
        'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
        'LU_Comm_res',  'Commute_Trip','Age','Trip_Distance']] # 'LU_Road_res', 'LU_Urban_res',
        df0['City']=city0
        df_all=df0.copy()

        cities0=['Leipzig','Magdeburg','Potsdam','Frankfurt am Main','Düsseldorf','Kassel']
        for city1 in cities0:
                df1=pd.read_csv('../outputs/Combined/' + city1 + '_UF.csv')
                df1['Commute_Trip']=0
                df1.loc[df1['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
                df1=df1.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
                #'PopDensity_res','BuildDensity_res', 
                'UrbPopDensity_res', 'UrbBuildDensity_res',
                'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                'LU_Comm_res', 'Commute_Trip','Age','Trip_Distance']]

                df1['City']=city1
                if len(df1.columns==df_all.columns):
                       df_all=pd.concat([df_all,df1])

        df_UF=df_all.copy()
    elif city=='France_other':
        city0='Clermont'
        df0=pd.read_csv('../outputs/Combined/' + city0 + '_UF.csv')
        df0['Commute_Trip']=0
        df0.loc[df0['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
        df0=df0.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
        #'PopDensity_res','BuildDensity_res', 
        'UrbPopDensity_res', 'UrbBuildDensity_res',
        'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
        'LU_Comm_res', 'Commute_Trip','Age','Trip_Distance']]

        df0['City']=city0
        df_all=df0.copy()

        cities0=['Toulouse','Montpellier','Lyon','Nantes','Nimes','Lille','Dijon']
        for city1 in cities0:
                df1=pd.read_csv('../outputs/Combined/' + city1 + '_UF.csv')
                df1['Commute_Trip']=0
                df1.loc[df1['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
                df1=df1.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
                #'PopDensity_res','BuildDensity_res', 
                'UrbPopDensity_res', 'UrbBuildDensity_res',
                'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                'LU_Comm_res', 'Commute_Trip','Age','Trip_Distance']]
                df1['City']=city1
                if len(df1.columns==df_all.columns):
                       df_all=pd.concat([df_all,df1])

        df_UF=df_all.copy()
    else:
            df=pd.read_csv('../outputs/Combined/' + city + '_UF.csv',dtype={'Ori_geocode': str, 'Des_geocode': str,'Res_geocode': str })
            df['Commute_Trip']=0
            df.loc[df['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
            df_UF=df.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
                            #'PopDensity_res','BuildDensity_res',
                            'UrbPopDensity_res', 'UrbBuildDensity_res',
                            'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                            'LU_Comm_res', 'Commute_Trip','Age','Trip_Distance']]

    count=df_UF.groupby('Res_geocode')['Trip_Distance'].count().reset_index()
    count.rename(columns={'Trip_Distance':'count'},inplace=True)
    df_UF=df_UF.groupby('Res_geocode').mean().drop_duplicates() #
    df_UF.reset_index(inplace=True)

    df_UF=df_UF.merge(count)
    df_UF=df_UF.loc[df_UF['count']>4,]
    df_agg=df_UF.copy()
    

    df_agg.sort_values(by='Res_geocode',inplace=True)
    df_agg.dropna(subset=['Trip_Distance'],inplace=True)
    if city in ['Leipzig','Germany_other']:
           df_agg=df_agg.loc[df_agg['UrbBuildDensity_res']<1e8,:]
#     if city=='Wien':
#            df_agg=df_agg.loc[:,['Res_geocode', 'DistCenter_res','UrbPopDensity_res','Commute_Trip','Trip_Distance','count']]
    # elif city in cities_small:
    #        df_agg=df_agg.loc[:,['Res_geocode', 'DistCenter_res','UrbPopDensity_res','Commute_Trip','LU_UrbFab_res','DistSubcenter_res','Trip_Distance','count']]
    # else:
    #        df_agg=df_agg.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res','UrbPopDensity_res',
    #                             'UrbBuildDensity_res','IntersecDensity_res',  'LU_UrbFab_res','Commute_Trip','Age','Trip_Distance','count']]

    target='Trip_Distance'

    X=df_agg.drop(columns=['Res_geocode','count',target])
    return X

# %%
X=vif_corr('Berlin')
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Berlin Germany
#                 Feature         VIF
# 0                 const  329.902832
# 1     DistSubcenter_res    1.388953
# 2        DistCenter_res    2.857265
# 3     UrbPopDensity_res    4.038368
# 4   UrbBuildDensity_res    3.456792
# 5   IntersecDensity_res    3.340469
# 6     street_length_res    2.082586
# 7         LU_UrbFab_res    2.353261
# 8           LU_Comm_res    1.816269
# 9          Commute_Trip    1.332942
# 10                  Age    1.672473
# <style type="text/css">
# #T_837da_row0_col0, #T_837da_row1_col1, #T_837da_row2_col2, #T_837da_row3_col3, #T_837da_row4_col4, #T_837da_row5_col5, #T_837da_row6_col6, #T_837da_row7_col7, #T_837da_row8_col8, #T_837da_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_837da_row0_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_837da_row0_col2, #T_837da_row3_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_837da_row0_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_837da_row0_col4, #T_837da_row6_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_837da_row0_col5 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_837da_row0_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_837da_row0_col7, #T_837da_row1_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_837da_row0_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_837da_row0_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_837da_row1_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_837da_row1_col2, #T_837da_row1_col3, #T_837da_row2_col0, #T_837da_row2_col9, #T_837da_row3_col1, #T_837da_row4_col5, #T_837da_row5_col4, #T_837da_row5_col6, #T_837da_row6_col7, #T_837da_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_837da_row1_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_837da_row1_col5, #T_837da_row2_col6 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_837da_row1_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_837da_row1_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_837da_row1_col9 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_837da_row2_col1, #T_837da_row3_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_837da_row2_col3 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_837da_row2_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_837da_row2_col5, #T_837da_row5_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_837da_row2_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_837da_row2_col8 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_837da_row3_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_837da_row3_col2 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_837da_row3_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_837da_row3_col6, #T_837da_row8_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_837da_row3_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_837da_row3_col8, #T_837da_row5_col0, #T_837da_row8_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_837da_row4_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_837da_row4_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_837da_row4_col2 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_837da_row4_col3, #T_837da_row4_col6 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_837da_row4_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_837da_row4_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_837da_row4_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_837da_row5_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_837da_row5_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_837da_row5_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_837da_row5_col8 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_837da_row5_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_837da_row6_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_837da_row6_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_837da_row6_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_837da_row6_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_837da_row6_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_837da_row6_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_837da_row6_col9, #T_837da_row9_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_837da_row7_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_837da_row7_col1, #T_837da_row7_col9 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_837da_row7_col2, #T_837da_row7_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_837da_row7_col3 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_837da_row7_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_837da_row7_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_837da_row7_col8 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_837da_row8_col0, #T_837da_row9_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_837da_row8_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_837da_row8_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_837da_row8_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_837da_row8_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_837da_row8_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_837da_row8_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_837da_row9_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_837da_row9_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_837da_row9_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_837da_row9_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_837da_row9_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_837da_row9_col7 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_837da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_837da_level0_col0" class="col_heading level0 col0" >DistSubcenter_res</th>
#       <th id="T_837da_level0_col1" class="col_heading level0 col1" >DistCenter_res</th>
#       <th id="T_837da_level0_col2" class="col_heading level0 col2" >UrbPopDensity_res</th>
#       <th id="T_837da_level0_col3" class="col_heading level0 col3" >UrbBuildDensity_res</th>
#       <th id="T_837da_level0_col4" class="col_heading level0 col4" >IntersecDensity_res</th>
#       <th id="T_837da_level0_col5" class="col_heading level0 col5" >street_length_res</th>
#       <th id="T_837da_level0_col6" class="col_heading level0 col6" >LU_UrbFab_res</th>
#       <th id="T_837da_level0_col7" class="col_heading level0 col7" >LU_Comm_res</th>
#       <th id="T_837da_level0_col8" class="col_heading level0 col8" >Commute_Trip</th>
#       <th id="T_837da_level0_col9" class="col_heading level0 col9" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_837da_level0_row0" class="row_heading level0 row0" >DistSubcenter_res</th>
#       <td id="T_837da_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_837da_row0_col1" class="data row0 col1" >0.427</td>
#       <td id="T_837da_row0_col2" class="data row0 col2" >-0.434</td>
#       <td id="T_837da_row0_col3" class="data row0 col3" >-0.413</td>
#       <td id="T_837da_row0_col4" class="data row0 col4" >-0.301</td>
#       <td id="T_837da_row0_col5" class="data row0 col5" >0.199</td>
#       <td id="T_837da_row0_col6" class="data row0 col6" >-0.247</td>
#       <td id="T_837da_row0_col7" class="data row0 col7" >-0.191</td>
#       <td id="T_837da_row0_col8" class="data row0 col8" >-0.126</td>
#       <td id="T_837da_row0_col9" class="data row0 col9" >0.179</td>
#     </tr>
#     <tr>
#       <th id="T_837da_level0_row1" class="row_heading level0 row1" >DistCenter_res</th>
#       <td id="T_837da_row1_col0" class="data row1 col0" >0.427</td>
#       <td id="T_837da_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_837da_row1_col2" class="data row1 col2" >-0.614</td>
#       <td id="T_837da_row1_col3" class="data row1 col3" >-0.720</td>
#       <td id="T_837da_row1_col4" class="data row1 col4" >-0.549</td>
#       <td id="T_837da_row1_col5" class="data row1 col5" >0.516</td>
#       <td id="T_837da_row1_col6" class="data row1 col6" >-0.241</td>
#       <td id="T_837da_row1_col7" class="data row1 col7" >-0.287</td>
#       <td id="T_837da_row1_col8" class="data row1 col8" >-0.158</td>
#       <td id="T_837da_row1_col9" class="data row1 col9" >0.

# %% [markdown]
# In Berlin, VIFs are acceptable, although all 3 density metrics are moderately high. Built-up density has a high correlation (0.716) with population density.
#
# Repeating without built-up density leads to notably lower VIFs for population and intersection density.

# %%
X=vif_corr('Berlin')
X.drop(columns='UrbBuildDensity_res',inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Berlin Germany
#                Feature         VIF
# 0                const  329.608467
# 1    DistSubcenter_res    1.387893
# 2       DistCenter_res    2.640121
# 3    UrbPopDensity_res    3.088421
# 4  IntersecDensity_res    3.281482
# 5    street_length_res    2.069237
# 6        LU_UrbFab_res    2.351799
# 7          LU_Comm_res    1.548786
# 8         Commute_Trip    1.305474
# 9                  Age    1.646900
# <style type="text/css">
# #T_e1272_row0_col0, #T_e1272_row1_col1, #T_e1272_row2_col2, #T_e1272_row3_col3, #T_e1272_row4_col4, #T_e1272_row5_col5, #T_e1272_row6_col6, #T_e1272_row7_col7, #T_e1272_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e1272_row0_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_e1272_row0_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_e1272_row0_col3, #T_e1272_row5_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e1272_row0_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_e1272_row0_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_
col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_30957_row5_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_30957_row5_col7, #T_30957_row7_col5 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_30957_row5_col8 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_30957_row6_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_30957_row6_col3 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_30957_row6_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_30957_row6_col9, #T_30957_row8_col3, #T_30957_row9_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_30957_row7_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_30957_row7_col2, #T_30957_row8_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_30957_row7_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_30957_row7_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_30957_row8_col1, #T_30957_row9_col6 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_30957_row8_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_30957_row8_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_30957_row8_col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_30957_row9_col2, #T_30957_row9_col3 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_30957_row9_col7 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_30957">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30957_level0_col0" class="col_heading level0 col0" >DistSubcenter_res</th>
#       <th id="T_30957_level0_col1" class="col_heading level0 col1" >DistCenter_res</th>
#       <th id="T_30957_level0_col2" class="col_heading level0 col2" >UrbPopDensity_res</th>
#       <th id="T_30957_level0_col3" class="col_heading level0 col3" >UrbBuildDensity_res</th>
#       <th id="T_30957_level0_col4" class="col_heading level0 col4" >IntersecDensity_res</th>
#       <th id="T_30957_level0_col5" class="col_heading level0 col5" >street_length_res</th>
#       <th id="T_30957_level0_col6" class="col_heading level0 col6" >LU_UrbFab_res</th>
#       <th id="T_30957_level0_col7" class="col_heading level0 col7" >LU_Comm_res</th>
#       <th id="T_30957_level0_col8" class="col_heading level0 col8" >Commute_Trip</th>
#       <th id="T_30957_level0_col9" class="col_heading level0 col9" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30957_level0_row0" class="row_heading level0 row0" >DistSubcenter_res</th>
#       <td id="T_30957_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_30957_row0_col1" class="data row0 col1" >0.618</td>
#       <td id="T_30957_row0_col2" class="data row0 col2" >-0.429</td>
#       <td id="T_30957_row0_col3" class="data row0 col3" >-0.514</td>
#       <td id="T_30957_row0_col4" class="data row0 col4" >-0.424</td>
#       <td id="T_30957_row0_col5" class="data row0 col5" >0.084</td>
#       <td id="T_30957_row0_col6" class="data row0 col6" >-0.092</td>
#       <td id="T_30957_row0_col7" class="data row0 col7" >-0.173</td>
#       <td id="T_30957_row0_col8" class="data row0 col8" >-0.081</td>
#       <td id="T_30957_row0_col9" class="data row0 col9" >0.004</td>
#     </tr>
#     <tr>
#       <th id="T_30957_level0_row1" class="row_heading level0 row1" >DistCenter_res</th>
#       <td id="T_30957_row1_col0" class="data row1 col0" >0.618</td>
#       <td id="T_30957_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_30957_row1_col2" class="data row1 col2" >-0.750</td>
#       <td id="T_30957_row1_col3" class="data row1 col3" >-0.725</td>
#       <td id="T_30957_row1_col4" class="data row1 col4" >-0.635</td>
#       <td id="T_30957_row1_col5" class="data row1 col5" >0.169</td>
#       <td id="T_30957_row1_col6" class="data row1 col6" >-0.325</td>
#       <td id="T_30957_row1_col7" class="data row1 col7" >0.009</td>
#       <td id="T_30957_row1_col8" class="data row1 col8" >0.028</td>
#       <td id="T_30957_row1_col9" class="data row1 col9" >-0.180</td>
#     </tr>
#     <tr>
#       <th id="T_30957_level0_row2" class="row_heading level0 row2" >UrbPopDensity_res</th>
#       <td id="T_30957_row2_col0" class="data row2 col0" >-0.429</td>
#       <td id="T_30957_row2_col1" class="data row2 col1" >-0.750</td>
#       <td id="T_30957_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_30957_row2_col3" class="data row2 col3" >0.728</td>
#       <td id="T_30957_row2_col4" class="data row2 col4" >0.669</td>
#       <td id="T_30957_row2_col5" class="

# %% [markdown]
# In Paris, VIFs are acceptable, although all 3 density metrics and distance to center are moderately high. Built-up density has a high correlation (0.728) with population density.
#
# Repeating without built-up density leads to notably lower VIF for population density, although it remains almost as high for intersection density.

# %%
X=vif_corr('Paris')
X.drop(columns='UrbBuildDensity_res',inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Paris France
#                Feature         VIF
# 0                const  528.835042
# 1    DistSubcenter_res    1.790058
# 2       DistCenter_res    3.624931
# 3    UrbPopDensity_res    2.951846
# 4  IntersecDensity_res    4.175236
# 5    street_length_res    1.928134
# 6        LU_UrbFab_res    2.681047
# 7          LU_Comm_res    1.988665
# 8         Commute_Trip    1.165444
# 9                  Age    1.322872
# <style type="text/css">
# #T_e943c_row0_col0, #T_e943c_row1_col1, #T_e943c_row2_col2, #T_e943c_row3_col3, #T_e943c_row4_col4, #T_e943c_row5_col5, #T_e943c_row6_col6, #T_e943c_row7_col7, #T_e943c_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e943c_row0_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_e943c_row0_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e943c_row0_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_e943c_row0_col4 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_e943c_row0_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_e943c_row0_col6, #T_e943c_row3_col7, #T_e943c_row6_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_e943c_row0_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e943c_row0_col8, #T_e943c_row8_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_e943c_row1_col0 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_e943c_row1_col2, #T_e943c_row1_col3, #T_e943c_row2_col0, #T_e943c_row2_col1, #T_e943c_row3_col0, #T_e943c_row3_col4, #T_e943c_row5_col6, #T_e943c_row6_col5, #T_e943c_row7_col8, #T_e943c_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e943c_row1_col4, #T_e943c_row8_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_e943c_row1_col5, #T_e943c_row2_col4, #T_e943c_row4_col5, #T_e943c_row5_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e943c_row1_col6, #T_e943c_row7_col6 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_e943c_row1_col7 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_e943c_row1_col8, #T_e943c_row4_col8 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_e943c_row2_col3 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_e943c_row2_col5 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_e943c_row2_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e943c_row2_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e943c_row2_col8 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_e943c_row3_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e943c_row3_col2 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_e943c_row3_col5 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_e943c_row3_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e943c_row3_col8, #T_e943c_row4_col0, #T_e943c_row7_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_e943c_row4_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_e943c_row4_col2, #T_e943c_row5_col1, #T_e943c_row5_col7, #T_e943c_row7_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e943c_row4_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e943c_row4_col6, #T_e943c_row6_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_e943c_row4_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e943c_row5_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e943c_row5_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_e943c_row5_col3 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_e943c_row5_col8 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_e943c_row6_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_e943c_row6_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_e943c_row6_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_e943c_row6_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e943c_row6_col8 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e943c_row7_col1, #T_e943c_row8_col5 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_e943c_row7_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_e943c_row7_col3 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_e943c_row7_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_e943c_row8_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_e943c_row8_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_e943c_row8_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_e943c_row8_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e943c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e943c_level0_col0" class="col_heading level0 col0" >DistSubcenter_res</th>
#       <th id="T_e943c_level0_col1" class="col_heading level0 col1" >DistCenter_res</th>
#       <th id="T_e943c_level0_col2" class="col_heading level0 col2" >UrbPopDensity_res</th>
#       <th id="T_e943c_level0_col3" class="col_heading level0 col3" >IntersecDensity_res</th>
#       <th id="T_e943c_level0_col4" class="col_heading level0 col4" >street_length_res</th>
#       <th id="T_e943c_level0_col5" class="col_heading level0 col5" >LU_UrbFab_res</th>
#       <th id="T_e943c_level0_col6" class="col_heading level0 col6" >LU_Comm_res</th>
#       <th id="T_e943c_level0_col7" class="col_heading level0 col7" >Commute_Trip</th>
#       <th id="T_e943c_level0_col8" class="col_heading level0 col8" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e943c_level0_row0" class="row_heading level0 row0" >DistSubcenter_res</th>
#       <td id="T_e943c_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_e943c_row0_col1" class="data row0 col1" >0.618</td>
#       <td id="T_e943c_row0_col2" class="data row0 col2" >-0.429</td>
#       <td id="T_e943c_row0_col3" class="data row0 col3" >-0.424</td>
#       <td id="T_e943c_row0_col4" class="data row0 col4" >0.084</td>
#       <td id="T_e943c_row0_col5" class="data row0 col5" >-0.092</td>
#       <td id="T_e943c_row0_col6" class="data row0 col6" >-0.173</td>
#       <td id="T_e943c_row0_col7" class="data row0 col7" >-0.081</td>
#       <td id="T_e943c_row0_col8" class="data row0 col8" >0.004</td>
#     </tr>
#     <tr>
#       <th id="T_e943c_level0_row1" class="row_heading level0 row1" >DistCenter_res</th>
#       <td id="T_e943c_row1_col0" class="data row1 col0" >0.618</td>
#       <td id="T_e943c_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_e943c_row1_col2" class="data row1 col2" >-0.750</td>
#       <td id="T_e943c_row1_col3" class="data row1 col3" >-0.635</td>
#       <td id="T_e943c_row1_col4" class="data row1 col4" >0.169</td>
#       <td id="T_e943c_row1_col5" class="data row1 col5" >-0.325</td>
#       <td id="T_e943c_row1_col6" class="data row1 col6" >0.009</td>
#       <td id="T_e943c_row1_col7" class="data row1 col7" >0.028</td>
#       <td id="T_e943c_row1_col8" class="data row1 col8" >-0.180</td>
#     </tr>
#     <tr>
#       <th id="T_e943c_level0_row2" class="row_heading level0 row2" >UrbPopDensity_res</th>
#       <td id="T_e943c_row2_col0" class="data row2 col0" >-0.429</td>
#       <td id="T_e943c_row2_col1" class="data row2 col1" >-0.750</td>
#       <td id="T_e943c_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_e943c_row2_col3" class="data row2 col3" >0.669</td>
#       <td id="T_e943c_row2_col4" class="data row2 col4" >-0.323</td>
#       <td id="T_e943c_row2_col5" class="data row2 col5" >0.498</td>
#       <td id="T_e943c_row2_col6" class="data row2 col6" >-0.248</td>
#       <td id="T_e943c_row2_col7" class="data row2 col7" >-0.041</td>
#       <td id="T_e943c_row2_col8" class="data row2 col8" >0.181</td>
#     </tr>
#     <tr>
#       <th id="T_e943c_level0_row3" class="row_heading level0 row3" >IntersecDensity_res</th>
#       <td id="T_e943c_row3_col0" class="data row3 col0" >-0.424</td>
#       <td id="T_e943c_row3_col1" class="data row3 col1" >-0.635</td>
#       <td id="T_e943c_row3_col2" class="data row3 col2" >0.669</td>
#       <td id="T_e943c_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_e943c_row3_col4" class="data row3 col4" >-0.588</td>
#       <td id="T_e943c_row3_col5" class="data row3 col5" >0.624</td>
#       <td id="T_e943c_row3_col6" class="data row3 col6" >-0.260</td>
#       <td id="T_e943c_row3_col7" class="data row3 col7" >0.011</td>
#       <td id="T_e943c_row3_col8" class="data row3 col8" >0.138</td>
#     </tr>
#     <tr>
#       <th id="T_e943c_level0_row4" class="row_heading level0 row4" >street_length_res</th>
#       <td id="T_e943c_row4_col0" class

# %%
X=vif_corr('Madrid')
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Madrid Spain
#                 Feature         VIF
# 0                 const  232.830446
# 1     DistSubcenter_res    1.338943
# 2        DistCenter_res    1.280247
# 3     UrbPopDensity_res    2.065712
# 4   UrbBuildDensity_res    1.125301
# 5   IntersecDensity_res    2.480232
# 6     street_length_res    2.130265
# 7         LU_UrbFab_res    2.168301
# 8           LU_Comm_res    1.338040
# 9          Commute_Trip    1.178086
# 10                  Age    1.385659
# <style type="text/css">
# #T_00558_row0_col0, #T_00558_row1_col1, #T_00558_row2_col2, #T_00558_row3_col3, #T_00558_row4_col4, #T_00558_row5_col5, #T_00558_row6_col6, #T_00558_row7_col7, #T_00558_row8_col8, #T_00558_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_00558_row0_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_00558_row0_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_00558_row0_col3, #T_00558_row3_col1, #T_00558_row5_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_00558_row0_col4, #T_00558_row3_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_00558_row0_col5 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_00558_row0_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_00558_row0_col7, #T_00558_row4_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_00558_row0_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_00558_row0_col9 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_00558_row1_col0, #T_00558_row7_col4 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_00558_row1_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_00558_row1_col3, #T_00558_row1_col9, #T_00558_row4_col0, #T_00558_row4_col5, #T_00558_row5_col2, #T_00558_row5_col4, #T_00558_row5_col6, #T_00558_row6_col7, #T_00558_row6_col8, #T_00558_row8_col9, #T_00558_row9_col1, #T_00558_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_00558_row1_col4, #T_00558_row8_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_00558_row1_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_00558_row1_col6, #T_00558_row6_col0, #T_00558_row7_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_00558_row1_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_00558_row1_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_00558_row2_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_00558_row2_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_00558_row2_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_00558_row2_col4 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_00558_row2_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_00558_row2_col6 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_00558_row2_col7, #T_00558_row3_col8 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_00558_row2_col8, #T_00558_row8_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_00558_row2_col9, #T_00558_row8_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_00558_row3_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_00558_row3_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_00558_row3_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_00558_row3_col6 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_00558_row3_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_00558_row3_col9, #T_00558_row8_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_00558_row4_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_00558_row4_col2 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_00558_row4_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_00558_row4_col6 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_00558_row4_col7, #T_00558_row7_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_00558_row4_col9 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_00558_row5_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_00558_row5_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_00558_row5_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_00558_row5_col7, #T_00558_row6_col5, #T_00558_row7_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_00558_row5_col8, #T_00558_row9_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_00558_row6_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_00558_row6_col2 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_00558_row6_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_00558_row6_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_00558_row6_col9 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_00558_row7_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_00558_row7_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_00558_row7_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_00558_row7_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_00558_row7_col9 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_00558_row8_col1, #T_00558_row9_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_00558_row8_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_00558_row8_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_00558_row8_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_00558_row9_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_00558_row9_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_00558_row9_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_00558_row9_col6 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_00558_row9_col7 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_00558">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00558_level0_col0" class="col_heading level0 col0" >DistSubcenter_res</th>
#       <th id="T_00558_level0_col1" class="col_heading level0 col1" >DistCenter_res</th>
#       <th id="T_00558_level0_col2" class="col_heading level0 col2" >UrbPopDensity_res</th>
#       <th id="T_00558_level0_col3" class="col_heading level0 col3" >UrbBuildDensity_res</th>
#       <th id="T_00558_level0_col4" class="col_heading level0 col4" >IntersecDensity_res</th>
#       <th id="T_00558_level0_col5" class="col_heading level0 col5" >street_length_res</th>
#       <th id="T_00558_level0_col6" class="col_heading level0 col6" >LU_UrbFab_res</th>
#       <th id="T_00558_level0_col7" class="col_heading level0 col7" >LU_Comm_res</th>
#       <th id="T_00558_level0_col8" class="col_heading level0 col8" >Commute_Trip</th>
#       <th id="T_00558_level0_col9" class="col_heading level0 col9" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00558_level0_row0" class="row_heading level0 row0" >DistSubcenter_res</th>
#       <td id="T_00558_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_00558_row0_col1" class="data row0 col1" >0.192</td>
#       <td id="T_00558_row0_col2" class="data row0 col2" >-0.384</td>
#       <td id="T_00558_row0_col3" class="data row0 col3" >-0.162</td>
#       <td id="T_00558_row0_col4" class="data row0 col4" >-0.390</td>
#       <td id="T_00558_row0_col5" class="data row0 col5" >0.318</td>
#       <td id="T_00558_row0_col6" class="data row0 col6" >-0.187</td>
#       <td id="T_00558_row0_col7" class="data row0 col7" >-0.151</td>
#       <td id="T_00558_row0_col8" class="data row0 col8" >-0.058</td>
#       <td id="T_00558_row0_col9" class="data row0 col9" >-0.121</td>
#     </tr>
#     <tr>
#       <th id="T_00558_level0_row1" class="row_heading level0 row1" >DistCenter_res</th>
#       <td id="T_00558_row1_col0" class="data row1 col0" >0.192</td>
#       <td id="T_00558_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_00558_row1_col2" class="data row1 col2" >-0.166</td>
#       <td id="T_00558_row1_col3" class="data row1 col3" >-0.220</td>
#       <td id="T_00558_row1_col4" class="data row1 col4" >-0.270</td>
#       <td id="T_00558_row1_col5" class="data row1 col5" >-0.003</td>
#       <td id="T_00558_row1_col6" class="data row1 col6" >-0.176</td>
#       <td id="T_00558_row1_col7" class="data row1 col7" >0.086</td>
#       <td id="T_00558_row1_col8" class="data row1 col8" >0.066</td>
#       <td id="T_00558_row1_col9" class="data row1 col9" >-0.285</td>
#     </tr>
#     <tr>
#       <th id="T_00558_level0_row2" class="row_heading level0 row2" >UrbPopDensity_res</th>
#       <td id="T_00558_row2_col0" class="data row2 col0" >-0.384</td>
#       <td id="T_00558_row2_col1" class="data row2 col1" >-0.1

# %% [markdown]
# In Madrid, VIFs are all low. No correlations are > 0.7.

# %%
X=vif_corr('Wien')
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
#
row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_b7747_row1_col2" class="data row1 col2" >-0.789</td>
#       <td id="T_b7747_row1_col3" class="data row1 col3" >-0.726</td>
#       <td id="T_b7747_row1_col4" class="data row1 col4" >-0.821</td>
#       <td id="T_b7747_row1_col5" class="data row1 col5" >0.654</td>
#       <td id="T_b7747_row1_col6" class="data row1 col6" >-0.749</td>
#       <td id="T_b7747_row1_col7" class="data row1 col7" >-0.194</td>
#       <td id="T_b7747_row1_col8" class="data row1 col8" >-0.179</td>
#       <td id="T_b7747_row1_col9" class="data row1 col9" >-0.137</td>
#     </tr>
#     <tr>
#       <th id="T_b7747_level0_row2" class="row_heading level0 row2" >UrbPopDensity_res</th>
#       <td id="T_b7747_row2_co

# %% [markdown]
# Vienna is very problematic in terms of correlations and VIF, possibly due to it's relatively small sample size.
#
# We can drop many features outside of our two main Urban Form feautres of interest, distance to center and population density.
# This helps a lot, although distance to center and population density have a high correlation (0.789).

# %%
X=vif_corr('Wien')
X.drop(columns=['IntersecDensity_res','LU_UrbFab_res','UrbBuildDensity_res','street_length_res','DistSubcenter_res'],inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Wien Austria
#              Feature         VIF
# 0              const  212.357275
# 1     DistCenter_res    3.054534
# 2  UrbPopDensity_res    3.323917
# 3        LU_Comm_res    1.082402
# 4       Commute_Trip    1.313317
# 5                Age    1.080270
# <style type="text/css">
# #T_6afc0_row0_col0, #T_6afc0_row1_col1, #T_6afc0_row2_col2, #T_6afc0_row3_col3, #T_6afc0_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6afc0_row0_col1, #T_6afc0_row0_col2, #T_6afc0_row1_col0, #T_6afc0_row3_col4, #T_6afc0_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6afc0_row0_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_6afc0_row0_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_6afc0_row1_col2, #T_6afc0_row3_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_6afc0_row1_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_6afc0_row1_col4, #T_6afc0_row4_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_6afc0_row2_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_6afc0_row2_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_6afc0_row2_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_6afc0_row2_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_6afc0_row3_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_6afc0_row3_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_6afc0_row4_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_6afc0_row4_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# </style>
# <table id="T_6afc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6afc0_level0_col0" class="col_heading level0 col0" >DistCenter_res</th>
#       <th id="T_6afc0_level0_col1" class="col_heading level0 col1" >UrbPopDensity_res</th>
#       <th id="T_6afc0_level0_col2" class="col_heading level0 col2" >LU_Comm_res</th>
#       <th id="T_6afc0_level0_col3" class="col_heading level0 col3" >Commute_Trip</th>
#       <th id="T_6afc0_level0_col4" class="col_heading level0 col4" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6afc0_level0_row0" class="row_heading level0 row0" >DistCenter_res</th>
#       <td id="T_6afc0_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_6afc0_row0_col1" class="data row0 col1" >-0.789</td>
#       <td id="T_6afc0_row0_col2" class="data row0 col2" >-0.194</td>
#       <td id="T_6afc0_row0_col3" class="data row0 col3" >-0.179</td>
#       <td id="T_6afc0_row0_col4" class="data row0 col4" >-0.137</td>
#     </tr>
#     <tr>
#       <th id="T_6afc0_level0_row1" class="row_heading level0 row1" >UrbPopDensity_res</th>
#       <td id="T_6afc0_row1_col0" class="data row1 col0" >-0.789</td>
#       <td id="T_6afc0_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_6afc0_row1_col2" class="data row1 col2" >0.047</td>
#       <td id="T_6afc0_row1_col3" class="data row1 col3" >0.389</td>
#       <td id="T_6afc0_row1_col4" class="data row1 col4" >0.042</td>
#     </tr>
#     <tr>
#       <th id="T_6afc0_level0_row2" class="row_heading level0 row2" >LU_Comm_res</th>
#       <td id="T_6afc0_row2_col0" class="data row2 col0" >-0.194</td>
#       <td id="T_6afc0_row2_col1" class="data row2 col1" >0.047</td>
#       <td id="T_6afc0_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_6afc0_row2_col3" class="data row2 col3" >0.044</td>
#       <td id="T_6afc0_row2_col4" class="data row2 col4" >0.052</td>
#     </tr>
#     <tr>
#       <th id="T_6afc0_level0_row3" class="row_heading level0 row3" >Commute_Trip</th>
#       <td id="T_6afc0_row3_col0" class="data row3 col0" >-0.179</td>
#       <td id="T_6afc0_row3_col1" class="data row3 col1" >0.389</td>
#       <td id="T_6afc0_row3_col2" class="data row3 col2" >0.044</td>
#       <td id="T_6afc0_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_6afc0_row3_col4" class="data row3 col4" >-0.206</td>
#     </tr>
#     <tr>
#       <th id="T_6afc0_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_6afc0_row4_col0" class="data row4 col0" >-0.137</td>
#       <td id="T_6afc0_row4_col1" class="data row4 col1" >0.042</td>
#       <td id="T_6afc0_row4_col2" class="data row4 col2" >0.052</td>
#       <td id="T_6afc0_row4_col3" class="data row4 col3" >-0.206</td>
#       <td id="T_6afc0_row4_col4" class="data row4 col4" >1.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Trying different model specifications, the linear model worked much better in terms of accuracy (r2) when commercial land-use and age were not included.
# Again perhaps due to the small sample size (44), the model is maybe not capable of handling too many input features.

# %%
X=vif_corr('Wien')
X.drop(columns=['IntersecDensity_res','LU_UrbFab_res','UrbBuildDensity_res','street_length_res','DistSubcenter_res','LU_Comm_res','Age'],inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Wien Austria
#              Feature        VIF
# 0              const  30.287055
# 1     DistCenter_res   2.798870
# 2  UrbPopDensity_res   3.194024
# 3       Commute_Trip   1.243340
# <style type="text/css">
# #T_13d1f_row0_col0, #T_13d1f_row1_col1, #T_13d1f_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_13d1f_row0_col1, #T_13d1f_row0_col2, #T_13d1f_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_13d1f_row1_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_13d1f_row2_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_13d1f_row2_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# </style>
# <table id="T_13d1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13d1f_level0_col0" class="col_heading level0 col0" >DistCenter_res</th>
#       <th id="T_13d1f_level0_col1" class="col_heading level0 col1" >UrbPopDensity_res</th>
#       <th id="T_13d1f_level0_col2" class="col_heading level0 col2" >Commute_Trip</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13d1f_level0_row0" class="row_heading level0 row0" >DistCenter_res</th>
#       <td id="T_13d1f_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_13d1f_row0_col1" class="data row0 col1" >-0.789</td>
#       <td id="T_13d1f_row0_col2" class="data row0 col2" >-0.179</td>
#     </tr>
#     <tr>
#       <th id="T_13d1f_level0_row1" class="row_heading level0 row1" >UrbPopDensity_res</th>
#       <td id="T_13d1f_row1_col0" class="data row1 col0" >-0.789</td>
#       <td id="T_13d1f_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_13d1f_row1_col2" class="data row1 col2" >0.389</td>
#     </tr>
#     <tr>
#       <th id="T_13d1f_level0_row2" class="row_heading level0 row2" >Commute_Trip</th>
#       <td id="T_13d1f_row2_col0" class="data row2 col0" >-0.179</td>
#       <td id="T_13d1f_row2_col1" class="data row2 col1" >0.389</td>
#       <td id="T_13d1f_row2_col2" class="data row2 col2" >1.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
X=vif_corr('France_other')
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_9f03f_row0_col1" class="data row0 col1" >0.459</td>
#       <td id="T_9f03f_row0_col2" class="data row0 col2" >-0.297</td>
#       <td id="T_9f03f_row0_col3" class="data row0 col3" >-0.293</td>
#       <td id="T_9f03f_row0_col4" class="data row0 col4" >-0.451</td>
#       <td id="T_9f03f_row0_col5" class="data row0 col5" >0.344</td>
#       <td id="T_9f03f_row0_col6" class="data row0 col6" >-0.307</td>
#       <td id="T_9f03f_row0_col7" class="data row0 col7" >-0.245</td>
#       <td id="T_9f03f_row0_col8" class="data row0 col8" >0.028</td>
#       <td id="T_9f03f_row0_col9" class="data row0 col9" >0.059</td>
#     </tr>
#     <tr>
#       <th id="T_9f03f_level0_row1" class="row_heading level0 row1" >DistCenter_res</th>
#       <td id="T_9f03f_row1_col0" class="data row1 col0" >0.459</td>
#       <td id="T_9f03f_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_9f03f_row1_col2" class="data row1 col2" >-0.375</td>
#       <td id="T_9f03f_row1_col3" class="data row1 col3" >-0.291</td>
#       <td id="T_9f03f_row1_col4" class="data row1 col4" >-0.462</td>
#       <td id="T_9f03f_row1_col5" class="data row1 col5" >0.267</td>
#       <td id="T_9f03f_row1_col6" class="data row1 col6" >-0.278</td>
#       <td id="T_9f03f_row1_col7" class="data row1 col7" >-0.193</td>
#       <td id="T_9f03f_row1_col8" class="data row1 col8" >-0.071</td>
#       <td id="T_9f03f_row1_col9" class="data row1 col9" >0.036</td>
#     </tr>
#     <tr>
#       <th id="T_9f03f_l

# %% [markdown]
# In rest of France, VIF is highest for intersection density, which has high correlation (although < 0.7) with population density.
#
# Without intersection density, max VIF is low (2.4) and no individual correlation is problematic.

# %%
X=vif_corr('France_other')
X.drop(columns=['IntersecDensity_res'],inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# France_other France
#                Feature         VIF
# 0                const  104.189437
# 1    DistSubcenter_res    1.457221
# 2       DistCenter_res    1.415082
# 3    UrbPopDensity_res    2.419412
# 4  UrbBuildDensity_res    2.406285
# 5    street_length_res    1.334422
# 6        LU_UrbFab_res    1.858778
# 7          LU_Comm_res    1.711509
# 8         Commute_Trip    1.066359
# 9                  Age    1.152301
# <style type="text/css">
# #T_87acd_row0_col0, #T_87acd_row1_col1, #T_87acd_row2_col2, #T_87acd_row3_col3, #T_87acd_row4_col4, #T_87acd_row5_col5, #T_87acd_row6_col6, #T_87acd_row7_col7, #T_87acd_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_87acd_row0_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_87acd_row0_col2, #T_87acd_row2_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_87acd_row0_col3, #T_87acd_row0_col6, #T_87acd_row1_col2, #T_87acd_row1_col3, #T_87acd_row2_col1, #T_87acd_row3_col8, #T_87acd_row4_col5, #T_87acd_row5_col0, #T_87acd_row5_col4, #T_87acd_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_87acd_row0_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_87acd_row0_col5, #T_87acd_row4_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_87acd_row0_col7, #T_87acd_row6_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_87acd_row0_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_87acd_row1_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_87acd_row1_col4 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_87acd_row1_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_87acd_row1_col6, #T_87acd_row8_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_87acd_row1_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_87acd_row1_col8, #T_87acd_row6_col7, #T_87acd_row7_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_87acd_row2_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_87acd_row2_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_87acd_row2_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_87acd_row2_col6, #T_87acd_row5_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_87acd_row2_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_87acd_row2_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_87acd_row3_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_87acd_row3_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_87acd_row3_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_87acd_row3_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_87acd_row3_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_87acd_row3_col6 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_87acd_row3_col7 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T
row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_87acd_row3_col4" class="data row3 col4" >-0.206</td>
#       <td id="T_87acd_row3_col5" class="data row3 col5" >0.041</td>

# %%
X=vif_corr('Germany_other')
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Germany_other Germany
#                 Feature         VIF
# 0                 const  223.647581
# 1     DistSubcenter_res    1.277411
# 2        DistCenter_res    2.019739
# 3     UrbPopDensity_res    2.792178
# 4   UrbBuildDensity_res    1.664990
# 5   IntersecDensity_res    6.274010
# 6     street_length_res    2.326492
# 7         LU_UrbFab_res    2.977671
# 8           LU_Comm_res    1.377117
# 9          Commute_Trip    1.591730
# 10                  Age    1.230517
# Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
# <style type="text/css">
# #T_2cc5a_row0_col0, #T_2cc5a_row1_col1, #T_2cc5a_row2_col2, #T_2cc5a_row3_col3, #T_2cc5a_row4_col4, #T_2cc5a_row5_col5, #T_2cc5a_row6_col6, #T_2cc5a_row7_col7, #T_2cc5a_row8_col8, #T_2cc5a_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2cc5a_row0_col1 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_2cc5a_row0_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_2cc5a_row0_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_2cc5a_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_2cc5a_row0_col5 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_2cc5a_row0_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_2cc5a_row0_col7, #T_2cc5a_row1_col3, #T_2cc5a_row3_col0, #T_2cc5a_row4_col1, #T_2cc5a_row4_col5, #T_2cc5a_row4_col9, #T_2cc5a_row5_col2, #T_2cc5a_row5_col4, #T_2cc5a_row5_col6, #T_2cc5a_row5_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2cc5a_row0_col8 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_2cc5a_row0_col9, #T_2cc5a_row4_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_2cc5a_row1_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_2cc5a_row1_col2, #T_2cc5a_row8_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_2cc5a_row1_col4, #T_2cc5a_row2_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_2cc5a_row1_col5 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_2cc5a_row1_col6, #T_2cc5a_row1_col7, #T_2cc5a_row9_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_2cc5a_row1_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_2cc5a_row1_col9, #T_2cc5a_row6_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_2cc5a_row2_col0, #T_2cc5a_row2_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_2cc5a_row2_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_2cc5a_row2_col4 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_2cc5a_row2_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_2cc5a_row2_col6, #T_2cc5a_row6_col2 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_2cc5a_row2_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_2cc5a_row2_col8 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_2cc5a_row3_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_2cc5a_row3_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_2cc5a_row3_col4 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_2cc5a_row3_col5, #T_2cc5a_row9_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_2cc5a_row3_col6, #T_2cc5a_row8_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_2cc5a_row3_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_2cc5a_row3_col8, #T_2cc5a_row8_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_2cc5a_row3_col9 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_2cc5a_row4_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_2cc5a_row4_col2 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_2cc5a_row4_col3 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_2cc5a_row4_col6 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_2cc5a_row4_col8 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_2cc5a_row5_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_2cc5a_row5_col1, #T_2cc5a_row9_col5 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_2cc5a_row5_col3, #T_2cc5a_row9_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_2cc5a_row5_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_2cc5a_row5_col9 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_2cc5a_row6_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_2cc5a_row6_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_2cc5a_row6_col4 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_2cc5a_row6_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_2cc5a_row6_col7 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_2cc5a_row6_col8 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_2cc5a_row6_col9 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_2cc5a_row7_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_2cc5a_row7_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_2cc5a_row7_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_2cc5a_row7_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_2cc5a_row7_col4 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_2cc5a_row7_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_2cc5a_row7_col6 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_2cc5a_row7_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_2cc5a_row7_col9, #T_2cc5a_row8_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_2cc5a_row8_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_2cc5a_row8_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_2cc5a_row8_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_2cc5a_row8_col4 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_2cc5a_row8_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_2cc5a_row9_col1 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_2cc5a_row9_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_2cc5a_row9_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_2cc5a_row9_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_2cc5a_row9_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2cc5a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cc5a_level0_col0" class="col_heading level0 col0" >DistSubcenter_res</th>
#       <th id="T_2cc5a_level0_col1" class="col_heading level0 col1" >DistCenter_res</th>
#       <th id="T_2cc5a_level0_col2" class="col_heading level0 col2" >UrbPopDensity_res</th>
#       <th id="T_2cc5a_level0_col3" class="col_heading level0 col3" >UrbBuildDensity_res</th>
#       <th id="T_2cc5a_level0_col4" class="col_heading level0 col4" >IntersecDensity_res</th>
#       <th id="T_2cc5a_level0_col5" class="col_heading level0 col5" >street_length_res</th>
#       <th id="T_2cc5a_level0_col6" class="col_heading level0 col6" >LU_UrbFab_res</th>
#       <th id="T_2cc5a_level0_col7" class="col_heading level0 col7" >LU_Comm_res</th>
#       <th id="T_2cc5a_level0_col8" class="col_heading level0 col8" >Commute_Trip</th>
#       <th id="T_2cc5a_level0_col9" class="col_heading level0 col9" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cc5a_level0_row0" class="row_heading level0 row0" >DistSubcenter_res</th>
#       <td id="T_2cc5a_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_2cc5a_row0_col1" class="data row0 col1" >0.298</td>
#       <td id="T_2cc5a_row0_col2" class="data row0 col2" >-0.207</td>
#       <td id="T_2cc5a_row0_col3" class="data row0 col3" >-0.383</td>
#       <td id="T_2cc5a_row0_col4" class="data row0 col4" >-0.246</td>
#       <td id="T_2cc5a_row0_col5" class="data row0 col5" >0.155</td>
#       <td id="T_2cc5a_row0_col6" class="data row0 col6" >-0.117</td>
#       <td id="T_2cc5a_row0_col7" class="data row0 col7" >-0.289</td>
#       <td id="T_2cc5a_row0_col8" class="data row0 col8" >-0.039</td>
#       <td id="T_2cc5a_row0_col9" class="data row0 col9" >0.018</td>
#     </tr>
#     <tr>
#       <th id="T_2cc5a_level0_row1" class="row_heading level0 row1" >DistCenter_res</th>
#       <td id="T_2cc5a_row1_col0" class="data row1 col0" >0.298</td>
#       <td id="T_2cc5a_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_2cc5a_row1_col2" class="data row1 col2" >-0.431</td>
#       <td id="T_2cc5a_row1_col3" class="data row1 col3" >-0.440</td>
#       <td id="T_2cc5a_row1_col4" class="data row1 col4" >-0.640</td>
#       <td id="T_2cc5a_row1_col5" class="data row1 col5" >0.356</td>
#       <td id="T_2cc5a_row1_col6" class="data row1 col6" >-0.451</td>
#       <td id="T_2cc5a_row1_col7" class="data row1 col7" >-0.239</td>
#       <td id="T_2cc5a_row1_col8" class="data row1 col8" >-0.273</td>
#       <td id="T_2cc5a_row1_col9" class="data row1 col9" >0.

# %% [markdown]
# In rest of Germany, intersection density VIF is high (6.3), and it is highly correlated with popultion density, street length and urban fabric land use.
#
# Dropping intersection density makes the VIF and correlations much better. One problematic correlation remains between population density and urban fabric land use (0.748), so we also drop urban fabric land use
#
# After dropping these two feautures, all VIFs are low, and no problematic correlations remain.

# %%
X=vif_corr('Germany_other')
X.drop(columns=['IntersecDensity_res','LU_UrbFab_res'],inplace=True)
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# Germany_other Germany
#                Feature         VIF
# 0                const  140.529973
# 1    DistSubcenter_res    1.256266
# 2       DistCenter_res    1.540123
# 3    UrbPopDensity_res    1.661801
# 4  UrbBuildDensity_res    1.658051
# 5    street_length_res    1.578462
# 6          LU_Comm_res    1.336953
# 7         Commute_Trip    1.290401
# 8                  Age    1.229880
# Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
# <style type="text/css">
# #T_281eb_row0_col0, #T_281eb_row1_col1, #T_281eb_row2_col2, #T_281eb_row3_col3, #T_281eb_row4_col4, #T_281eb_row5_col5, #T_281eb_row6_col6, #T_281eb_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_281eb_row0_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_281eb_row0_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_281eb_row0_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_281eb_row0_col4, #T_281eb_row1_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_281eb_row0_col5, #T_281eb_row1_col3, #T_281eb_row2_col4, #T_281eb_row2_col7, #T_281eb_row3_col0, #T_281eb_row3_col1, #T_281eb_row4_col2, #T_281eb_row4_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_281eb_row0_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_281eb_row0_col7, #T_281eb_row7_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_281eb_row1_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_281eb_row1_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_281eb_row1_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_281eb_row1_col5, #T_281eb_row7_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_281eb_row1_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_281eb_row2_col0, #T_281eb_row6_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_281eb_row2_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_281eb_row2_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_281eb_row2_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_281eb_row2_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_281eb_row3_col2, #T_281eb_row4_col1, #T_281eb_row7_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_281eb_row3_col4, #T_281eb_row4_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_281eb_row3_col5 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_281eb_row3_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_281eb_row3_col7, #T_281eb_row7_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_281eb_row4_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_281eb_row4_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_281eb_row4_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_281eb_row5_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_281eb_row5_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_281eb_row5_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_281eb_row5_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_281eb_row5_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_281eb_row5_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_281eb_row5_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_281eb_row6_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_281eb_row6_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_281eb_row6_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_281eb_row6_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_281eb_row6_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_281eb_row6_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_281eb_row7_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_281eb_row7_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_281eb_row7_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_281eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_281eb_level0_col0" class="col_heading level0 col0" >DistSubcenter_res</th>
#       <th id="T_281eb_level0_col1" class="col_heading level0 col1" >DistCenter_res</th>
#       <th id="T_281eb_level0_col2" class="col_heading level0 col2" >UrbPopDensity_res</th>
#       <th id="T_281eb_level0_col3" class="col_heading level0 col3" >UrbBuildDensity_res</th>
#       <th id="T_281eb_level0_col4" class="col_heading level0 col4" >street_length_res</th>
#       <th id="T_281eb_level0_col5" class="col_heading level0 col5" >LU_Comm_res</th>
#       <th id="T_281eb_level0_col6" class="col_heading level0 col6" >Commute_Trip</th>
#       <th id="T_281eb_level0_col7" class="col_heading level0 col7" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_281eb_level0_row0" class="row_heading level0 row0" >DistSubcenter_res</th>
#       <td id="T_281eb_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_281eb_row0_col1" class="data row0 col1" >0.298</td>
#       <td id="T_281eb_row0_col2" class="data row0 col2" >-0.207</td>
#       <td id="T_281eb_row0_col3" class="data row0 col3" >-0.383</td>
#       <td id="T_281eb_row0_col4" class="data row0 col4" >0.155</td>
#       <td id="T_281eb_row0_col5" class="data row0 col5" >-0.289</td>
#       <td id="T_281eb_row0_col6" class="data row0 col6" >-0.039</td>
#       <td id="T_281eb_row0_col7" class="data row0 col7" >0.018</td>
#     </tr>
#     <tr>
#       <th id="T_281eb_level0_row1" class="row_heading level0 row1" >DistCenter_res</th>
#       <td id="T_281eb_row1_col0" class="data row1 col0" >0.298</td>
#       <td id="T_281eb_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_281eb_row1_col2" class="data row1 col2" >-0.431</td>
#       <td id="T_281eb_row1_col3" class="data row1 col3" >-0.440</td>
#       <td id="T_281eb_row1_col4" class="data row1 col4" >0.356</td>
#       <td id="T_281eb_row1_col5" class="data row1 col5" >-0.239</td>
#       <td id="T_281eb_row1_col6" class="data row1 col6" >-0.273</td>
#       <td id="T_281eb_row1_col7" class="data row1 col7" >0.285</td>
#     </tr>
#     <tr>
#       <th id="T_281eb_level0_row2" class="row_heading level0 row2" >UrbPopDensity_res</th>
#       <td id="T_281eb_row2_col0" class="data row2 col0" >-0.207</td>
#       <td id="T_281eb_row2_col1" class="data row2 col1" >-0.431</td>
#       <td id="T_281eb_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_281eb_row2_col3" class="data row2 col3" >0.317</td>
#       <td id="T_281eb_row2_col4" class="data row2 col4" >-0.525</td>
#       <td id="T_281eb_row2_col5" class="data row2 col5" >0.006</td>
#       <td id="T_281eb_row2_col6" class="data row2 col6" >0.127</td>
#       <td id="T_281eb_row2_col7" class="data row2 col7" >-0.292</td>
#     </tr>
#     <tr>
#       <th id="T_281eb_level0_row3" class="row_heading level0 row3" >UrbBuildDensity_res</th>
#       <td id="T_281eb_row3_col0" class="data row3 col0" >-0.383</td>
#       <td id="T_281eb_row3_col1" class="data row3 col1" >-0.440</td>
#       <td id="T_281eb_row3_col2" class="data row3 col2" >0.317</td>
#       <td id="T_281eb_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_281eb_row3_col4" class="data row3 col4" >-0.226</td>
#       <td id="T_281eb_row3_col5" class="data row3 col5" >0.443</td>
#       <td id="T_281eb_row3_col6" class="data row3 col6" >0.276</td>
#       <td id="T_281eb_row3_col7" class="data row3 col7" >-0.092</td>
#     </tr>
#     <tr>
#       <th id="T_281eb_level0_row4" class="row_heading level0 row4" >street_length_res</th>
#       <td id="T_281eb_row4_col0" class="data row4 col0" >0.155</td>
#       <td id="T_281eb_row4_col1" class="data row4 col1" >0.356</td>
#       <td id="T_281eb_row4_col2" class="data row4 col2" >-0.525</td>
#       <td id="T_281eb_row4_col3" class="data row4 col3" >-0.226</td>
#       <td id="T_281eb_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_281eb_row4_col5" class="data row4 col5" >-0.033</td>
#       <td id="T_281eb_row4_col6" class="data row4 col6" >-0.331</td>
#       <td id="T_281eb_row4_col7" class="data row4 col7" >0.318</td>
#     </tr>
#     <tr>
#       <th id="T_281eb_level0_row5" class="row_heading level0 row5" >LU_Comm_res</th>
#       <td id="T_281eb_row5_col0" class="data row5 col0" >-0.289</td>
#       <td id="T_281eb_row5_col1" class="data row5 col1" >-0.239</td>
#       <td id="T_281eb_row5_col2" class="data row5 col2" >0.006</td>
#       <td id="T_281eb_row5_col3" class="data row5 col3" >0.443</td>
#       <td id="T_281eb_row5_col4" class="data row5 col4" >-0.033</td>
#       <td id="T_281eb_row5_col5" class="data

# %%
# now check for all cities data combined
city0='Berlin'
df0=pd.read_csv('../outputs/Combined/' + city0 + '_UF.csv')
df0['Commute_Trip']=0
df0.loc[df0['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
#print(len(df0.columns), 'columns in the data for ', city0)
df0=df0.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
#'PopDensity_res','BuildDensity_res', 
'UrbPopDensity_res', 'UrbBuildDensity_res',
'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
'LU_Comm_res',  'Commute_Trip','Age','Trip_Distance']] # 'LU_Road_res', 'LU_Urban_res',
df0['City']=city0
df0['Country']='Germany'
df_all=df0.copy()

cities0=['Dresden','Leipzig','Magdeburg','Potsdam','Frankfurt am Main','Düsseldorf','Kassel']
for city1 in cities0:
        print(city1)
        df1=pd.read_csv('../outputs/Combined/' + city1 + '_UF.csv')
        df1['Commute_Trip']=0
        df1.loc[df1['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
        df1=df1.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
        #'PopDensity_res','BuildDensity_res', 
        'UrbPopDensity_res', 'UrbBuildDensity_res',
        'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
        'LU_Comm_res', 'Commute_Trip','Age','Trip_Distance']]
        #print(len(df1.columns), 'columns in the data for ', city1)
        df1['City']=city1
        df1['Country']='Germany'
        if len(df1.columns==df_all.columns):
                df_all=pd.concat([df_all,df1])
                print(city1, 'added.')
                print(len(df_all), 'rows in the combined dataframe')
df_DE=df_all.copy()
# FR, other
city0='Clermont'
df0=pd.read_csv('../outputs/Combined/' + city0 + '_UF.csv')
df0['Commute_Trip']=0
df0.loc[df0['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
df0=df0.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
#'PopDensity_res','BuildDensity_res', 
'UrbPopDensity_res', 'UrbBuildDensity_res',
'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
'LU_Comm_res', 'Commute_Trip','Age','Trip_Distance']]
#print(len(df0.columns), 'columns in the data for ', city0)
df0['City']=city0
df0['Country']='France'
df_all=df0.copy()

cities0=['Toulouse','Montpellier','Lyon','Nantes','Nimes','Lille','Dijon','Paris']
for city1 in cities0:
        print(city1)
        df1=pd.read_csv('../outputs/Combined/' + city1 + '_UF.csv')
        df1['Commute_Trip']=0
        df1.loc[df1['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
        df1=df1.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
        #'PopDensity_res','BuildDensity_res', 
        'UrbPopDensity_res', 'UrbBuildDensity_res',
        'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
        'LU_Comm_res', 'Commute_Trip','Age','Trip_Distance']]
#print(len(df0.columns), 'columns in the data for ', city0)
        print(len(df1.columns), 'columns in the data for ', city1)
        df1['City']=city1
        df1['Country']='France'
        if len(df1.columns==df_all.columns):
                df_all=pd.concat([df_all,df1])
                print(city1, 'added.')
                print(len(df_all), 'rows in the combined dataframe')
df_FR=df_all.copy()
df=pd.read_csv('../outputs/Combined/' + 'Madrid' + '_UF.csv',dtype={'Ori_geocode': str, 'Des_geocode': str,'Res_geocode': str })
df['Commute_Trip']=0
df.loc[df['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
df_UF=df.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
                #'PopDensity_res','BuildDensity_res',
                'UrbPopDensity_res', 'UrbBuildDensity_res',
                'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                'LU_Comm_res', 'Commute_Trip','Age','Trip_Distance']]
df_UF['City']='Madrid'
df_UF['Country']='Spain'
df_Madrid=df_UF.copy()
df=pd.read_csv('../outputs/Combined/' + 'Wien' + '_UF.csv',dtype={'Ori_geocode': str, 'Des_geocode': str,'Res_geocode': str })
df['Commute_Trip']=0
df.loc[df['Trip_Purpose_Agg']=='Home↔Work','Commute_Trip']=1
df_UF=df.loc[:,['Res_geocode', 'DistSubcenter_res', 'DistCenter_res',
                #'PopDensity_res','BuildDensity_res',
                'UrbPopDensity_res', 'UrbBuildDensity_res',
                'IntersecDensity_res', 'street_length_res', 'LU_UrbFab_res',#'bike_lane_share_res',
                'LU_Comm_res', 'Commute_Trip','Age','Trip_Distance']]
df_UF['City']='Wien'
df_UF['Country']='Austria'
df_Wien=df_UF.copy()
del df_UF
df_UF=pd.concat([df_DE,df_FR,df_Madrid,df_Wien],ignore_index=True)
df_UF['Res_geocode']= df_UF['City'] + '_' + df_UF['Res_geocode'].astype(str)
df_UF.drop(columns='City',inplace=True)
# Out:
# Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
# Dresden
# Dresden added.
# 126573 rows in the combined dataframe
# Leipzig
# Leipzig added.
# 138169 rows in the combined dataframe
# Magdeburg
# Magdeburg added.
# 147545 rows in the combined dataframe
# Potsdam
# Potsdam added.
# 153368 rows in the combined dataframe
# Frankfurt am Main
# Frankfurt am Main added.
# 159403 rows in the combined dataframe
# Düsseldorf
# Düsseldorf added.
# 183247 rows in the combined dataframe
# Kassel
# Kassel added.
# 192614 rows in the combined dataframe
# Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
# Toulouse
# 12 columns in the data for  Toulouse
# Toulouse added.
# 49864 rows in the combined dataframe
# Montpellier
# 12 columns in the data for  Montpellier
# Montpellier added.
# 80127 rows in the combined dataframe
# Lyon
# 12 columns in the data for  Lyon
# Lyon added.
# 132884 rows in the combined dataframe
# Nantes
# 12 columns in the data for  Nantes
# Nantes added.
# 167926 rows in the combined dataframe
# Nimes
# 12 columns in the data for  Nimes
# Nimes added.
# 179143 rows in the combined dataframe
# Lille
# 12 columns in the data for  Lille
# Lille added.
# 215992 rows in the combined dataframe
# Dijon
# 12 columns in the data for  Dijon
# Dijon added.
# 230246 rows in the combined dataframe
# Paris
# 12 columns in the data for  Paris
# Paris added.
# 293160 rows in the combined dataframe

# %%
count=df_UF.groupby('Res_geocode')['Trip_Distance'].count().reset_index()
count.rename(columns={'Trip_Distance':'count'},inplace=True)
df_UF=df_UF.groupby('Res_geocode').mean().drop_duplicates() #
df_UF.reset_index(inplace=True)

df_UF=df_UF.merge(count)
df_UF=df_UF.loc[df_UF['count']>4,]
df_agg=df_UF.copy()

# %% [markdown]
# No correlations or VIFs are high enough for concern with all data combined

# %%
X=df_agg.drop(columns=['Res_geocode','count','Trip_Distance'])
X_selc = add_constant(X)
vif=pd.Series([variance_inflation_factor(X_selc.values, i) for i in range(X_selc.shape[1])], index=X_selc.columns)
vif=vif.to_frame().reset_index()
vif.columns=['Feature','VIF']
corr = X.corr()
print(vif)
corr.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
#                 Feature         VIF
# 0                 const  127.579704
# 1     DistSubcenter_res    1.392080
# 2        DistCenter_res    1.250864
# 3     UrbPopDensity_res    2.068669
# 4   UrbBuildDensity_res    1.205950
# 5   IntersecDensity_res    3.281989
# 6     street_length_res    1.926918
# 7         LU_UrbFab_res    1.731523
# 8           LU_Comm_res    1.229449
# 9          Commute_Trip    1.140095
# 10                  Age    1.064541
# <style type="text/css">
# #T_f18ef_row0_col0, #T_f18ef_row1_col1, #T_f18ef_row2_col2, #T_f18ef_row3_col3, #T_f18ef_row4_col4, #T_f18ef_row5_col5, #T_f18ef_row6_col6, #T_f18ef_row7_col7, #T_f18ef_row8_col8, #T_f18ef_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f18ef_row0_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_f18ef_row0_col2, #T_f18ef_row0_col3, #T_f18ef_row0_col7, #T_f18ef_row4_col0, #T_f18ef_row4_col1, #T_f18ef_row4_col5, #T_f18ef_row5_col2, #T_f18ef_row5_col4, #T_f18ef_row5_col6, #T_f18ef_row7_col9, #T_f18ef_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f18ef_row0_col4, #T_f18ef_row6_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_f18ef_row0_col5, #T_f18ef_row3_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_f18ef_row0_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_f18ef_row0_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f18ef_row0_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_f18ef_row1_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_f18ef_row1_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_f18ef_row1_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_f18ef_row1_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_f18ef_row1_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_f18ef_row1_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_f18ef_row1_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_f18ef_row1_col8, #T_f18ef_row6_col9, #T_f18ef_row9_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_f18ef_row1_col9 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_f18ef_row2_col0, #T_f18ef_row9_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f18ef_row2_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f18ef_row2_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f18ef_row2_col4 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_f18ef_row2_col5, #T_f18ef_row3_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_f18ef_row2_col6 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_f18ef_row2_col7 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f18ef_row2_col8, #T_f18ef_row9_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_f18ef_row2_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f18ef_row3_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_f18ef_row3_col1, #T_f18ef_row6_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_f18ef_row3_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_f18ef_row3_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_f18ef_row3_col6, #T_f18ef_row4_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f18ef_row3_col7, #T_f18ef_row4_col7, #T_f18ef_row8_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_f18ef_row3_col9 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_f18ef_row4_col2 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_f18ef_row4_col6 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_f18ef_row4_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_f18ef_row4_col9 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f18ef_row5_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T